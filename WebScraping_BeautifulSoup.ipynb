# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.5)

# %%
from bs4 import BeautifulSoup

# %%
path = '/content/index2.html'

with open(path,"r") as f:
  doc = BeautifulSoup(f,"html.parser")

print(doc)
# Out:
# <html>
# <head>
# <title>Your Title Here</title>
# </head>
# <body bgcolor="FFFFFF">
# <center><img align="BOTTOM" src="clouds.jpg"/> </center>
# <hr/>
# <a href="http://somegreatsite.com">Link Name</a>
#
# is a link to another nifty site
#
# <h1>This is a Header</h1>
# <h2>This is a Medium Header</h2>
#
# Send me mail at <a href="mailto:support@yourcompany.com">
#
# support@yourcompany.com</a>.
#
# <p> This is a new paragraph!
#
# <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p></p></body>
# </html>

# %%
print(doc.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    Your Title Here
#   </title>
#  </head>
#  <body bgcolor="FFFFFF">
#   <center>
#    <img align="BOTTOM" src="clouds.jpg"/>
#   </center>
#   <hr/>
#   <a href="http://somegreatsite.com">
#    Link Name
#   </a>
#   is a link to another nifty site
#   <h1>
#    This is a Header
#   </h1>
#   <h2>
#    This is a Medium Header
#   </h2>
#   Send me mail at
#   <a href="mailto:support@yourcompany.com">
#    support@yourcompany.com
#   </a>
#   .
#   <p>
#    This is a new paragraph!
#    <p>
#     <b color="red">
#      This is a new paragraph!
#     </b>
#     <br/>
#     <b>
#      <i>
#       This is a new sentence without a paragraph break, in bold italics.
#      </i>
#     </b>
#     <hr/>
#    </p>
#   </p>
#  </body>
# </html>

# %%
tag = doc.title
print(tag)
# Out:
# <title>Your Title Here</title>

# %%
tag = doc.body
print(tag.h2)
print(tag.a)
# Out:
# <h2>This is a Medium Header</h2>
# <a href="http://somegreatsite.com">Link Name</a>

# %%
## to modify the content

tag = doc.title
tag.string = 'This is altered Title'
print(tag)
print(doc.title)
# Out:
# <title>This is altered Title</title>
# <title>This is altered Title</title>

# %%
## find only gives the first instance
tag = doc.find('a')
print(tag)
# Out:
# <a href="http://somegreatsite.com">Link Name</a>

# %%
## find_all only gives all the instance
tag = doc.find_all('a')
print(tag)
# Out:
# [<a href="http://somegreatsite.com">Link Name</a>, <a href="mailto:support@yourcompany.com">
#
# support@yourcompany.com</a>]

# %%
## find_all only gives all the instance and to access specific objects inside it
tag = doc.find_all('p')
print(tag[1])
# Out:
# <p> <b color="red">This is a new paragraph!</b>
# <br/> <b><i>This is a new sentence without a paragraph break, in bold italics.</i></b>
# <hr/>
# </p>

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)

# %%
import requests

# %%
url='https://www.newegg.ca/gigabyte-geforce-rtx-4070-gv-n4070wf3oc-12gd/p/N82E16814932611'

# %%
results = requests.get(url)

print(results.text)
# Out:
# <!DOCTYPE html><html lang="en-ca" class="show-tab-store "><head><title>GIGABYTE NVIDIA GeForce RTX 4070 Overclock Gaming 12GB WINDFORCE GDDR6X PCI Express 4.0 ATX Graphics Card GV-N4070WF3 OC -12GD - Newegg - Newegg.ca</title><meta charSet="utf-8"/><meta http-equiv="content-type" content="text/html; charset=UTF-8"/><meta name="twitter:card" content="summary_large_image"/><meta name="referrer" content="always"/><meta name="keywords" content="Newegg, Newegg.ca, GIGABYTE WINDFORCE GeForce RTX 4070 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4070WF3OC-12GD"/><meta name="description" content="Get GIGABYTE GeForce RTX 4070 WINDFORCE Overclock edition, featuring 12GB GDDR6X memory, PCI Express 4.0 and superior cooling. Order today at Newegg."/><meta property="og:image" content="https://c1.neweggimages.com/ProductImage/14-932-611-V01.jpg"/><meta property="og:description" content="Buy GIGABYTE WINDFORCE GeForce RTX 4070 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4070WF3OC-12GD with fast shipping and top-rated customer service. Once you know, you Newegg!"/><meta property="og:title" content="GIGABYTE NVIDIA GeForce RTX 4070 Overclock Gaming 12GB WINDFORCE GDDR6X PCI Express 4.0 ATX Graphics Card GV-N4070WF3 OC -12GD - Newegg - Newegg.com"/><meta property="og:url" content="https://www.newegg.ca/gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x/p/N82E16814932611"/><meta property="og:type" content="website"/><meta name="language" content="english"/><meta name="copyright" content="© 2000-2024 Newegg Inc."/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><meta name="robots" content="index,follow,max-image-preview:large,max-snippet:-1"/><meta name="X-DNS-Prefetch-Control" content="on"/><meta name="format-detection" content="telephone=no"/><link rel="shortcut icon" type="image/x-icon" href="https://c1.neweggimages.com/WebResource/ngm/newegg.ico"/><link rel="canonical" href="https://www.newegg.ca/gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x/p/N82E16814932611"/><link rel="amphtml" href="https://www.newegg.ca/amp/gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x/p/N82E16814932611"/><link rel="preconnect" href="https://c1.neweggimages.com/" crossorigin=""/><link rel="preconnect" href="https://imk.neweggimages.com/" crossorigin=""/><script type="text/javascript">!function(){try{if(!navigator.userAgent.match(/Newegg.+App/ig))return;var e=document.createElement("style");e.innerText="html.sticky-header-top body{padding-top: 0px!important;}header{display: none;}footer{display: none;}",document.querySelector("head").append(e)}catch(t){console.log(t)}}();</script><script>window.__PolyfillScripts__={"core-js":"https://c1.neweggimages.com/WebResource/Scripts/WWW/core-js.polyfill.min.js","intersection-observer":"https://c1.neweggimages.com/WebResource/Scripts/WWW/intersection-observer.polyfill.min.js"}</script><script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/runtime~product~ProductDetail-ae2c5243.js"></script><script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/polyfillEntry-a43910b7.js"></script><link href="https://c1.neweggimages.com/WebResource/Themes/WWW/CSS/ProductDetail-1063e43d35.css" rel="stylesheet"/><script id="kimoi" type="application/json">[{"type":"setCookie","payload":{"cookie":"CountryRegion","value":"CAN"}},{"type":"setCookie","payload":{"cookie":"LanguageCode","value":"en"}},{"type":"setSubCookie","payload":{"cookie":"CountryConfiguration","subCookieKey":"CurrencyCode","subCookieValue":"CAD"}}]</script>
# <script>(window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);</script>
#                               <script>!function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="VVKLK-DW65Z-X2EAR-S9CNF-C36HD",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"VVKLK-DW65Z-X2EAR-S9CNF-C36HD";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="ejbyjvqx3suvazv3rqoq-f-31eb6b97a-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"37","ak.cp":"639580","ak.ai":parseInt("275154",10),"ak.ol":"0","ak.cr":35,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"100883eb","ak.r":47480,"ak.a2":n,"ak.m":"x","ak.n":"essl","ak.bpcip":"34.67.132.0","ak.cport":46482,"ak.gh":"23.32.237.169","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"bbr","ak.t":"1723567133","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"95","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);</script></head><body><div><script type="text/javascript">;;;(function(){var e=document.querySelector('meta[name="viewport"]'),t=document.createElement("meta");t. ...
# <script type="text/javascript">(function(){var darkv = document.cookie.match('(^|;) ?NV_Theme=([^;]*)(;|$)');var dark = darkv ? darkv[2] : "false";if (dark == "true") {if(!document.getElementById('NewTemplate')){jQuery('html').addClass('dark-mode');}else{document.documentElement.classList.add("dark-mode")}}var style = document.createElement("style");var darkCss='#Dark_Mode{display:none;}.header2021-toggle{z-index:5}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:20px}.header2021-toggle:hover{transform:scale(1)}.header2021-toggle:hover .bg-lightgray{background-color:rgba(235,235,235,1)}.header2021-toggle .toggle-body{border:1px solid #212121;border-radius:30px}.header2021-toggle .toggle-body-inner:after{border-radius:30px;width:30px;top:0;bottom:0;margin-left:-1px;box-shadow:0 1px 6px 0 rgb(0 0 0 / 16%)}.header2021-toggle .toggle-handle{font-size:20px;color:#474747}.header2021-toggle .dark-mode-tooltip{padding:5px 15px;white-space:nowrap}.header2021-toggle.menu.at-bottom .menu-body{left:auto;right:0;margin-top:12px;text-align:left}.header2021-toggle.at-bottom>.menu-arrow{left:auto;right:20px;text-align:left}.header2021-toggle.at-bottom>.menu-body>.menu-arrow{left:auto!important;right:20px}.dark-mode .header2021-toggle .toggle-handle.take-on{padding-left:8px}.dark-mode .header2021-toggle:hover .bg-lightgray{background-color:#ea7421}.dark-mode .header2021-toggle .toggle-body{border:1px solid #835b38}.dark-mode .header2021-toggle .bg-lightgray{background-color:#e05d00}.dark-mode .header2021-toggle input[type="checkbox"]:checked ~ .toggle-body .toggle-body-inner:after{margin-right:0;margin-left:0;top:0}.dark-mode .header2021-toggle .toggle-body-inner:after{box-shadow:0 6px 6px 0 rgb(0 0 0 / 16%)}@media(max-width:599px){.header2021-inner{padding:15px 2px}.header2021-logo{width:60px}.header2021-country.header2021-nav:not(:first-child){margin-left:15px}.header2021-toggle .bg-lightgray{background:#fff}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:15px}.header2021-toggle .toggle-body{min-width:30px;height:30px;border-radius:50%}.header2021-toggle .toggle-body-inner{width:100%;height:100%;transform:translateX(0);justify-content:center;align-items:center}.header2021-toggle .toggle-handle{height:100%;line-height:1.1;padding:0;font-size:22px;justify-content:center;z-index:2}.header2021-toggle .toggle-body-inner:after{content:none}.header2021-toggle .toggle-handle.take-off{padding:0}.header2021-toggle .toggle-handle.take-on,.header2021-toggle.menu.at-bottom .menu-body{display:none}.dark-mode .header2021-toggle .toggle-handle.take-on{display:flex;padding:0}.dark-mode .header2021-toggle .toggle-handle.take-off{display:none}.section-right>.line-vertical-new{margin:0 0 0 10px}}@media(max-width:350px){.header2021-nav-inner,.header2021-nav.menu .header2021-nav-inner{padding-left:26px;height:26px;min-height:26px}.header2021-country-flag{width:26px;height:26px}.header2021-nav-icon{width:26px;height:26px;line-height:26px;font-size:24px;top:2px}.header2021-nav ~ .header2021-nav{margin-left:5px}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:10px}.header2021-toggle .toggle-body{min-width:24px;height:24px}.header2021-toggle .toggle-handle{font-size:16px}}';try{style.appendChild(document.createTextNode(darkCss));}catch(ex){style.styleSheet.cssText = darkCss;}var head = document.getElementsByTagName("head")[0];head&&head.appendChild(style);var darkbut = jQuery('<div class="header2021-nav header2021-toggle toggle toggle-m menu at-bottom"><label id="darkLabel"><input type="checkbox" id="checkdarkmode"><span class="toggle-body bg-lightgray font-l"><span class="toggle-body-inner"><span class="toggle-handle take-on">&#9790;</span><span class="toggle-handle take-off ">&#9728;</span></span></span></label><div id="darkModal" class="menu-body bg-white radius-s shadow-level-1"><i class="menu-arrow"></i><p class="dark-mode-tooltip">Switch to Dark Mode</p></div></div>');jQuery(document).ready(function (){jQuery('.head ...
# </div><div><script type="text/javascript">;;; (function () { var ADRPattern = /Newegg.+Android.+App/ig; var IPNPattern = /Newegg.+(iPhone|iPad).+App/ig; var Container = { APP: 'GTM-TF5LHJ5', EGG: 'GTM-WJ2PC5C' }; function LoadContainer(w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://imk.neweggimages.com/webresource/scripts/gatra/lib/app/neggtm.js?negg=2&id=' + i + dl; f.parentNode.insertBefore(j, f); }; if (navigator.userAgent.match(ADRPattern) || navigator.userAgent.match(IPNPattern)) { LoadContainer(window, document, 'script', 'dataLayer', Container.APP); } else { } })();</script></div><div><script type="text/javascript">;;; (function () { var ADRPattern = /Newegg.+Android.+App/ig; var IPNPattern = /Newegg.+(iPhone|iPad).+App/ig; var Container = { APP: 'GTM-TF5LHJ5', EGG: 'GTM-W26F4QT' }; function LoadContainer(w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://imk.neweggimages.com/webresource/scripts/gatra/lib/can/neggtm.js?negg=2&id=' + i + dl; f.parentNode.insertBefore(j, f); }; if (navigator.userAgent.match(ADRPattern) || navigator.userAgent.match(IPNPattern)) {  } else { LoadContainer(window, document, 'script', 'dataLayer', Container.EGG); } })();</script></div><div><script type="text/javascript" >;(function () {var s = document.createElement("script");
#   s.defer=true;
#  s.type = "text/javascript";
#    s.src = "//imk.neweggimages.com/webresource/scripts/plugin/inhousebiztra.js";
#  var node = document.getElementsByTagName("script")[0];
#  node.parentNode.insertBefore(s, node);})();</script></div><div><style>@import url(https://c1.neweggimages.com/webresource/themes/WWW/CSS/fixManufactory.css)</style></div><div> <script type="text/javascript" src="https://c1.neweggimages.com/webresource/Scripts/Others/TopRatedSeller/new-feature-script.2.0.5.min.js" defer></script></div><div><script type="text/javascript" defer src='https://c1.neweggimages.com/webresource/Scripts/Others/ShippingEstimate/shippingestimate-v.7.1.min.js'></script></div><div>
#             <script type="text/javascript">
#             ;;;(function() {
#       window.__ga_biItems=[{pages: ["all"],events:["view_item","select_item","view_item_list"],property:["item_range","spa","best_seller","lowest_price","deal_type","boost_type"]}];    window.__ga_forbiddenList = [{
#  pages: ["all"],
#   events:["recommendation_module_click","search_ahead_view","legacy_view","legacy_click","view_item_list","recommendation_module_view","spa_view","spa_click","search_ahead_click","infocard_view","infocard_click","web_notification_view","trending_keywords_view","select_item"],
#   clearGa4: true,
#   clearInhouse:false,
#       }
#    ];
#                 window.__ga_mappingAdobe = [{
#    events:["event63"],
#    eventName:"legacy_click",
#    mapping:{
#   legacy_element_value:"evar78",
#  module_name:"evar79",
#    products:"products"
#     }
#    },{
#    events:["event168"],
#    eventName:"legacy_view",
#    mapping:{
#   legacy_element_value:"evar78",
#    products:"products"
#     }
#    },{
#  events: ["event21"],
#  eventname: "email_subscribed",
#  mapping:{
#  }
#  }, {
#  events: ["event40"],
#  eventname: "modules_click", mapping:{
#  module_name: "eVar103"
#  }
#  }, {
#  events: ["event91"],
#  eventname: "modules_view", mapping:{
#  module_name: "eVar79"
#  }
#  }];
#                 window.__ga_linkInternalFilters = "javascript:,newegg.com,gamecrate.com,abs.com,checkout.us.zip.co,zip.co,checkout.quadpay.com,3debspay.boc.cn,alfabank.ru,arcot.com,billmelater.com,citibank.co.kr,ftpsllc.com,garanti.com.tr,hyundaicard.com,kbcard.com,keb.co.kr,masterpass.com,mycardsecure.com,newegg3.com.sh,paypal.com,samsungcard.co.kr,secure2gw.ro,securecode.com,secureserver.net,securesuite.co.uk,securesuite.net,shinhancard.com,verifiedbyvisa.com,visa.com,visa.com.ar,web.v.me,secondfunnel.com,cardinalcommerce.com,secure.neweggbusiness.com,www-newegg-com.cdn.ampproject.org,www.newegg.ca,secure.newegg.ca,kb.neweggbusiness.com,www.neweggbusiness.com,help.newegg.ca,secure.m.newegg.ca,secure.newegg.com,www.rosewill.com,neweggbusiness.com,sellerportal.newegg.cn,partner.gqc.newegg.space,help.neweggbusiness.com,secure.newegg6.com.sh,sellerportal62780.gqc.newegg.space,central3.newegg.org,partner.newegg.cn,secure.newegg4.com.sh,newegg.io,newegggpu.com,justgpu.com";
#             })()
#         </script>
# </li><li>PCI Express 4.0 x16</li></ul></div><div class="product-msg-group"></div></div></div><div class="product-contents"><div class="page-section"><div class="page-section-inner"><div id="PDP_product-recommend"><div class="preload-paragraph preload-recommend no-title"><div class="preload-head"><div class="preload-head-circle preload-assembler"></div><div class="preload-head-title preload-assembler"></div></div><div class="preload-content"><div class="preload-body"><div class="preload-body-left"><div class="preload-body-left-top preload-assembler"></div><div class="preload-body-left-bottom preload-assembler"></div></div><span class="preload-body-plus">+</span><div class="preload-body-right"><div class="preload-body-right-top"><div class="preload-body-right-thin preload-assembler"></div><div class="preload-body-right-thin preload-assembler"></div><div class="preload-body-right-thin preload-assembler"></div></div><div class="preload-body-right-items"><div class="preload-body-right-item preload-assembler"></div><div class="preload-body-right-item preload-assembler"></div><div class="preload-body-right-item preload-assembler"></div><div class="preload-body-right-item preload-assembler"></div></div></div></div><div class="preload-foot"><div class="preload-foot-left"><div class="preload-foot-title preload-assembler"></div><div class="preload-foot-action"><div class="preload-foot-action-sm preload-assembler"></div><span>+</span><div class="preload-foot-action-lm preload-assembler"></div></div></div><div class="preload-foot-right preload-assembler"></div></div></div></div><div class="preload-paragraph preload-recommend is-items"><div class="preload-head"><div class="preload-head-title preload-assembler"></div></div><div class="preload-content"><div class="preload-body"><div class="preload-items"><div class="preload-item"><div class="preload-item-top preload-assembler"></div><div class="preload-item-bottom"><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div></div></div><div class="preload-item"><div class="preload-item-top preload-assembler"></div><div class="preload-item-bottom"><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div></div></div><div class="preload-item"><div class="preload-item-top preload-assembler"></div><div class="preload-item-bottom"><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div></div></div><div class="preload-item"><div class="preload-item-top preload-assembler"></div><div class="preload-item-bottom"><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div></div></div><div class="preload-item"><div class="preload-item-top preload-assembler"></div><div class="preload-item-bottom"><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div><div class="preload-item-content preload-assembler"></div></div></div></div></div></div></div></div><div id="product-details" class="tab-box"><div class="tab-navs"><div class="tab-nav active">Overview</div><div class="tab-nav">Specs</div><div class="tab-nav">Reviews</div></div><div class="tab-panes"><div class="tab-pane" style="display:block"><div id="product-overview" class="article"><div><style>
# #overview-content.sku-14-932-611 .a_plus_content:before,
# #overview-content.sku-14-932-611 .a_plus_content:after,
# #overview-content.sku-14-932-611 .a_plus_group:before,
# #overview-content.sku-14-932-611 .a_plus_group:after,
# #overview-content.sku-14-932-611 .a_plus_module:before,
# #overview-content.sku-14-932-611 .a_plus_module:after,
# #overview-content.sku-14-932-611 .a_plus_info:after {content:''; display: table; clear: both;}
#
# #overview-content.sku-14-932-611 * {-webkit-box-sizing: border-box; -moz-box-sizing: border-box; box-sizing: border-box; font:14px arial,helvetica,sans-serif; line-height: 1.4em;}
#
# #overview-content.sku-14-932-611 .a_plus_content {background-color:black; color:white;}
#
# /* Picture as Background */
# #overview-content.sku-14-932-611 .a_plus_content .bg1 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video%20Card%20-%20Nvidia/14-932-611/1-bg.jpg) no-repeat center center; background-size:cover; padding:3em 2em;}
# #overview-content.sku-14-932-611 .a_plus_content .bg2 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video%20Card%20-%20Nvidia/14-932-611/4-bg.jpg) no-repeat center center; background-size:cover; padding:3em 0;}
# #overview-content.sku-14-932-611 .a_plus_content .bg3 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video%20Card%20-%20Nvidia/14-932-611/6-bg.jpg) no-repeat center center; background-size:cover; padding:3em 2em;}
#
# #overview-content.sku-14-932-611 .a_plus_content .bg20 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/banner.png) repeat-y center center; background-size:cover;}
# #overview-content.sku-17-233-041 .a_plus_content .bg30 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/banner.png) no-repeat fixed center; color:white; padding:3em 2em;}
# #overview-content.sku-17-233-041 .a_plus_content .bg31 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/banner.png) no-repeat fixed center; color:white; padding:3em 2em;}
# #overview-content.sku-17-233-041 .a_plus_content .bg32 {background:url(//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/banner.png) no-repeat fixed center; color:white; padding:3em 2em;}
#
#
#
# /* titles */
# #overview-content.sku-14-932-611 .a_plus_content h3.text1 {font-size:1.8em; font-weight:bold; line-height: 1.2em;}
# #overview-content.sku-14-932-611 .a_plus_content h3.text2 {font-size:1.6em; font-weight:500; line-height: 1.2em;}
# #overview-content.sku-14-932-611 .a_plus_content h3.text3 {font-size:1.4em; font-weight:bold; line-height: 1.2em; }
# #overview-content.sku-14-932-611 .a_plus_content h3.text4 {font-size:1.2em; font-weight:bold; line-height: 1.1em; text-shadow:-1px -1px 0 #fff, 1px -1px 0 #fff, -1px 1px 0 #fff, 1px 1px 0 #fff;}
# #overview-content.sku-14-932-611 .a_plus_content h3.text5 {font-size:1.2em; font-weight:bold; line-height: 1.1em; margin-bottom: 1em; padding-bottom: 0.6em; margin-left: -0.5em; padding-left: 0.5em; background-image: linear-gradient(to right, #ff98ea 0% , #c572ff 20%, #655cfc 40%, #00ffff 60%, #f0ffc4 80%, #ff98ea 100%)}
# #overview-content.sku-14-932-611 .a_plus_content h3.text6 {font-size:1.2em; font-weight:bold; line-height: 1.1em; background: linear-gradient(to right, #e1a93a, #ffe1ab, #ce9d45, #ffe1ab, #e1a93a);color: #f2c673; -webkit-background-clip: text; -webkit-text-fill-color: transparent; text-shadow: 0 0 0 rgb(255 255 255 / 10%);}
# #overview-content.sku-14-932-611 .a_plus_content h3.text7 {font-size:1.2em; font-weight:bold; line-height: 1.1em; text-shadow: 2px 3px 5px #121212;}
#
#
#
# #overview-content.sku-14-932-611 .a_plus_content .font1 {font-size:2.8em; font-weight:bold;}
# #overview-content.sku-14-932-611 .a_plus_content .font2 {font-size:1.6em; font-weight:bold;}
#
# /* Sellpoints */
# #overview-content.sku-14-932-611 .feature_detail {font-size:1.6em;text-align:center; padding:30px; text-align:center; margin-bottom:10px; background-color:#C4AE89; color:white; }
# #overview-content.sku-14-932-611 .feature_detail span {padding:0 15px; border-right:2px solid white; line-height:1.8em;}
# #overview-content.sku-14-932-611 .feature_detail span:last-child {border-right:none;}
#
#
# /* divider*/
# #overview-content.sku-14-932-611 .a_plus_content .dividervc {width:100%; height:1em; border-top:0.1em solid #d4d4d4; margin:0.3em auto; }
# #overview-content.sku-14-932-611 .a_plus_content .dividervc1 {background-image:linear-gradient(90deg, #ff8500, #d1050c, #7328cd); height:5px;}
# #overview-content.sku-14-932-611 .a_plus_content .dividervc2 {width:100%; height:1em; border-top:0.1em solid #d4d4d4; margin:0.3em 0; }
# #overview-content.sku-14-932-611 .dot {height: 5px; width: 5px; background-color: #bbb;  border-radius: 50%;  display: inline-block;}
#
#
# /* headers */
# #overview-content.sku-14-932-611 .a_plus_content .section_head1 {border-bottom: 1px solid #000000; color:#ffffff; clear: both; height:28px; margin:20px auto; width: 100%; text-align:center; margin-top:3em;}
# #overview-content.sku-14-932-611 .a_plus_content .section_head1 span {background-color:#000000; font-size:1.6em; line-height:42px; padding:5px 23px; }
# #overview-content.sku-14-932-611 .a_plus_content .section_head2 {font-size:1.4em; text-align:center; padding:10px; margin-bottom:10px; background-color:#008ea0; color:white;}
# #overview-content.sku-14-932-611 .a_plus_content .section_head3 {margin: 0px auto 20px; padding: 10px 0px 10px 15px; border-left: 12px solid #00693C; background: #EFEFEF none repeat scroll 0% 0%; color: #00693C;text-align: left;font-size: 1.3em;font-weight: bold;}
# #overview-content.sku-14-932-611 .a_plus_content .section_head4 {background-color: #32d5df; /* For browsers that do not support gradients */    background-image: linear-gradient(to bottom right, #32d5df, #3adf32); /* Standard syntax (must be last) */ padding:1em;}
#
#
# /* Big box */
# #overview-content.sku-14-932-611 .a_plus_module {position: relative; padding: 0; overflow: hidden;}
# #overview-content.sku-14-932-611 .a_plus_info p {display: block; margin: 0.5em 0;}
#
#
#
# /* Image box */
# #overview-content.sku-14-932-611 .a_plus_img {margin: 0 auto; padding: 0;}
# #overview-content.sku-14-932-611 .a_plus_img img {display: block; margin: auto; max-width: 100%;}
# #overview-content.sku-14-932-611 .a_plus_img + .a_plus_info { margin: 0; }
#
# #overview-content.sku-14-932-611 .a_plus_content .txt_align_center {text-align: center; }
# #overview-content.sku-14-932-611 .a_plus_content .txt_align_left {text-align:left;}
# #overview-content.sku-14-932-611 .a_plus_content .txt_align_right {text-align:right;}
# #overview-content.sku-14-932-611 .a_plus_content .txt_align_left img,
# #overview-content.sku-14-932-611 .a_plus_content .txt_align_center img {margin-right:5px; max-width:100%;}
# #overview-content.sku-14-932-611 .a_plus_info img {max-width:100%;}
#
#
#
# /* List */
# #overview-content.sku-14-932-611 .a_plus_info ul,
# #overview-content.sku-14-932-611 .a_plus_info ol { margin: 1em 0; }
# #overview-content.sku-14-932-611 .a_plus_info ul {list-style-type: disc; list-style-position: outside;	padding-left: 25px;}
# #overview-content.sku-14-932-611 .a_plus_info li { margin-bottom: 1em; list-style-image: url("//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/5.jpg")}
# #overview-content.sku-14-932-611 .a_plus_info li:last-child { margin-bottom: 0; }
#
#
#
# /* group */
# #overview-content.sku-14-932-611 .a_plus_group { margin: 1em 0; }
# #overview-content.sku-14-932-611 .a_plus_group:first-child { margin-top: 0; }
# #overview-content.sku-14-932-611 .a_plus_group:last-child { margin-bottom: 0; }
#
#
# /* table styles */
# #overview-content.sku-14-932-611 table.table1 {width: 100%;  border-collapse: collapse;}
#
# /* Zebra striping */
# #overview-content.sku-14-932-611 tr.row1:nth-of-type(odd) {background: #eee;}
# #overview-content.sku-14-932-611 th.head1 {background: #333; color: white; font-weight: bold; }
# #overview-content.sku-14-932-611 td.column1,
# #overview-content.sku-14-932-611 th.head1 {padding: 10px; border: 1px solid #ccc; text-align: left;}
#
#
# /* note */
# #overview-content.sku-14-932-611 .has_note {font-size:1.1em; font-weight:bold; text-align:left;}
# #overview-content.sku-14-932-611 .note_detail {font-size:0.9em; font-style:italic; }
#
#
# /* space */
# #overview-content.sku-14-932-611 .a_plus_content .space1 {margin-top:1em;}
# #overview-content.sku-14-932-611 .a_plus_content .space2 {margin-top:2em;}
# #overview-content.sku-14-932-611 .a_plus_content .space3 {margin-top:3em;}
# #overview-content.sku-14-932-611 .a_plus_content .space0 {margin-top:0;}
# #overview-content.sku-14-932-611 .a_plus_content .space0b {margin-bottom:0;}
# #overview-content.sku-14-932-611 .a_plus_content .space1b {margin-bottom:1em;}
# #overview-content.sku-14-932-611 .a_plus_content .space2b {margin-bottom:2em;}
# #overview-content.sku-14-932-611 .a_plus_content .space3b {margin-bottom:3em;}
# #overview-content.sku-14-932-611 .a_plus_content .padding1 {padding-top:1em;}
# #overview-content.sku-14-932-611 .a_plus_content .padding2 {padding-top:2em;}
# #overview-content.sku-14-932-611 .a_plus_content .padding3 {padding-top:3em;}
# #overview-content.sku-14-932-611 .a_plus_content .padding1b {padding-bottom:1em;}
# #overview-content.sku-14-932-611 .a_plus_content .padding2b {padding-bottom:2em;}
# #overview-content.sku-14-932-611 .a_plus_content .padding3b {padding-bottom:3em;}
#
#
# /* background color */
# #overview-content.sku-14-932-611 .bgcolor1 {background-color:#18191B;}
# #overview-content.sku-14-932-611 .bgcolor2 {background: rgba(0, 0, 0, 0.7);}
# #overview-content.sku-14-932-611 .bgcolor3 {background-color:#659747;}
# #overview-content.sku-14-932-611 .bgcolor4 {background-color:#1657e7;}
# #overview-content.sku-14-932-611 .bgcolor5 {background-color:#1657e7;}
#
#
# /* font color */
# #overview-content.sku-14-932-611 .color1 {color:aqua;}
# #overview-content.sku-14-932-611 .color2 {color:#878582;text-shadow: 3px 5px 5px rgba(0, 0, 0, 0.5);}
# #overview-content.sku-14-932-611 .color3 {color:#AA9480;text-shadow: 3px 5px 5px rgba(0, 0, 0, 0.5);}
# #overview-content.sku-14-932-611 .color4 {color:white;}
#
#
#
# /* Box width */
# #overview-content.sku-14-932-611 .width1 {width:95%; margin:1em auto 0; }
# #overview-content.sku-14-932-611 .width2 {width:85%; margin:1em auto 0; }
#
#
# #overview-content.sku-14-932-611 .a_plus_cell .a_plus_info {padding-top:1em; }
#
# #overview-content.sku-14-932-611 .border1 {border:1px solid gray;}
#
#
# @media (min-width: 768px) {
#
# 	/* has background */
# 	#overview-content.sku-14-932-611 .position1 {position:absolute; margin:0; left:16%; top:12%; width:65%; }
# 	#overview-content.sku-14-932-611 .position2 {position:absolute; margin:0; left:25%; bottom:6%; width:50%; text-align:center;}
#
# 	#overview-content.sku-14-932-611 .position3 {position:absolute; margin:0; left:10%; top:12%; width:80%; text-align:center;}
#
# 	#overview-content.sku-14-932-611 .position4 {position:absolute; margin:0; left:2%; top:8%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
# 	#overview-content.sku-14-932-611 .position5 {position:absolute; margin:0; left:50%; top:3%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
# 	#overview-content.sku-14-932-611 .position6 {position:absolute; margin:0; left:50%; top:3%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
# 	#overview-content.sku-14-932-611 .position7 {position:absolute; margin:0; left:50%; top:3%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
# 	#overview-content.sku-14-932-611 .position8 {position:absolute; margin:0; left:50%; top:3%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
# 	#overview-content.sku-14-932-611 .position9 {position:absolute; margin:0; left:50%; top:3%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
# 	#overview-content.sku-14-932-611 .position10 {position:absolute; margin:0; left:50%; top:3%; width:40%; background: rgba(255, 255, 255, 0.4); padding:1em;}
#
#
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left .a_plus_img	{ float: left; width:40%;}
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right .a_plus_img { float: right; width:40%;}
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left .a_plus_img + .a_plus_info { float: left; width:60%; }
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right .a_plus_img + .a_plus_info { float: right; width:60%; }
#
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left2 .a_plus_img	{ float: left; width:60%;}
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right2 .a_plus_img { float: right; width:60%;}
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left2 .a_plus_img + .a_plus_info { float: left; width:40%; }
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right2 .a_plus_img + .a_plus_info { float: right; width:40%; }
#
#
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left .a_plus_info,
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left2 .a_plus_info {padding:0 20px 20px 20px;}
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right .a_plus_info,
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right2 .a_plus_info {padding:0 20px 20px 20px;}
# 	#overview-content.sku-14-932-611 .a_plus_content .a_plus_info.padding-a {padding-top:2em;}
# 	#overview-content.sku-14-932-611 .a_plus_content .a_plus_info.padding-b {padding-top:4em;}
# 	#overview-content.sku-14-932-611 .a_plus_content .a_plus_info.padding-c {padding-top:7em;}
#
#
#
#     #overview-content.sku-14-932-611 .col-1 {width: 8.33%;}
#     #overview-content.sku-14-932-611 .col-2 {width: 16.66%;}
#     #overview-content.sku-14-932-611 .col-3 {width: 25%;}
#     #overview-content.sku-14-932-611 .col-4 {width: 33.33%;}
#     #overview-content.sku-14-932-611 .col-5 {width: 41.66%;}
#     #overview-content.sku-14-932-611 .col-6 {width: 50%;}
#     #overview-content.sku-14-932-611 .col-7 {width: 58.33%;}
#     #overview-content.sku-14-932-611 .col-8 {width: 66.66%;}
#     #overview-content.sku-14-932-611 .col-9 {width: 75%;}
#     #overview-content.sku-14-932-611 .col-10 {width: 83.33%;}
#     #overview-content.sku-14-932-611 .col-11 {width: 91.66%;}
#     #overview-content.sku-14-932-611 .col-12 {width: 100%;}
#
# 	#overview-content.sku-14-932-611 div[class*="col-"] {padding:2em; flex:1; }
# 	#overview-content.sku-14-932-611 div[class*="col-"].border_right {border-right:solid #e6e6e6 0.5em;}
# 	#overview-content.sku-14-932-611 .a_plus_group {display:flex; width:100%;}
#
# 	#overview-content.sku-14-932-611 .a_plus_group .a_plus_cell.width-a {width:41.3%; margin:3em 0.1em;}
# 	#overview-content.sku-14-932-611 .a_plus_group .a_plus_cell.width-b {width:58.4%; margin:3em 0.1em;}
#
# 	}
#
#
#
#
# @media (max-width: 767px) {
#
# 	#overview-content.sku-14-932-611 .a_plus_group .a_plus_cell { margin: 1em 0.5em; }
# 	#overview-content.sku-14-932-611 .a_plus_group .a_plus_cell:first-child { margin-top: 0; }
# 	#overview-content.sku-14-932-611 .a_plus_group .a_plus_cell:last-child { margin-bottom: 0; }
#
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left .a_plus_info,
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_left2 .a_plus_info,
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right .a_plus_info,
# 	#overview-content.sku-14-932-611 .a_plus_module.img_at_right2 .a_plus_info {padding:5px 10% 3em 10%; }
#
#
#
# 	/* all divs with name including position */
# 	#overview-content.sku-14-932-611 div[class*="position"] {padding:0.5em 1em 4em;}
#
#
# 	/* tables */
# 	/* Force table to not be like tables anymore */
# 	#overview-content.sku-14-932-611 table.table1,
# 	#overview-content.sku-14-932-611 table.table1 thead.head1,
# 	#overview-content.sku-14-932-611 table.table1 tbody,
# 	#overview-content.sku-14-932-611 table.table1 th.head1,
# 	#overview-content.sku-14-932-611 table.table1 td.column1,
# 	#overview-content.sku-14-932-611 tr.row1 {display: block;}
#
# 	/* Hide table headers (but not display: none;, for accessibility) */
# 	#overview-content.sku-14-932-611 table.table1 thead.head1 tr.row1 { position: absolute; top: -9999px;left: -9999px;}
#
# 	#overview-content.sku-14-932-611 tr.row1 { border: 1px solid #ccc; }
#
# 	#overview-content.sku-14-932-611 td.column1 { /* Behave  like a "row" */	border: none; border-bottom: 1px solid #eee; position: relative;padding-left: 50%; }
#
# 	#overview-content.sku-14-932-611 td.column1:before {/* Now like a table header */position: absolute;	/* Top/left values mimic padding */	top: 6px;left: 6px;	width: 45%; padding-right: 10px; white-space: nowrap;}
#
# 	/*	Label the data	*/
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(1):before { content: "First Name"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(2):before { content: "Last Name"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(3):before { content: "Job Title"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(4):before { content: "HS100"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(5):before { content: "HS105"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(6):before { content: "HS100 KIT"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(7):before { content: "HS105 KIT"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(8):before { content: "HS110 KIT"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(9):before { content: "RE270K"; }
# 	#overview-content.sku-14-932-611 td.column1:nth-of-type(10):before { content: "RE370K"; }
#
#
# 	/* several groups For mobile devices: */
# 	#overview-content.sku-14-932-611 div[class*="col-"] {
# 		width: 100%;
# 	}
#
# }
# </style>
#
#
#
#
# <div id="overview-content" class="sku-14-932-611">
#     <article class="a_plus_content">
#
# 		<div class="bg1">
#
#
#
# 			<div class="a_plus_group width1">
# 				<div class="a_plus_cell col-6">
# 					<div class="a_plus_module">
# 						<div class="a_plus_info space1">
# 							<h3 class="a_plus_title text1">
# 								KEY FEATURE
# 							</h3>
# 						</div>
# 						<div class="txt_align_left space1">
# 							<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/1a.png" alt="GV-N4070WF3OC-12GD Video Card">
# 						</div>
# 						<div class="a_plus_info space1">
# 							<ul>
# 								<li>Powered by NVIDIA DLSS 3, ultra-efficient Ada Lovelace arch, and full ray tracing</li>
# 								<li>4th Generation Tensor Cores: Up to 4x performance with DLSS 3 vs. brute-force rendering</li>
# 								<li>3rd Generation RT Cores: Up to 2X ray tracing performance</li>
# 								<li>Powered by GeForce RTX™ 4070</li>
# 								<li>Integrated with 12GB GDDR6X 192bit memory interface</li>
# 								<li>WWINDFORCE Cooling System</li>
# 								<li>Protection metal back plate</li>
# 							</ul>
# 						</div>
#
# 						<h3 class="a_plus_title text1 space2">
# 							CORE CLOCK
# 						</h3>
# 						<p>TBD</p>
# 						<div class="txt_align_left space1">
# 							<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/1b.png" alt="GV-N4070WF3OC-12GD Video Card">
# 							<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/1c.png" alt="GV-N4070WF3OC-12GD Video Card">
# 						</div>
# 					</div>
# 				</div>
# 				<div class="a_plus_cell col-6">
# 					<div class="a_plus_module">
# 						<div class="txt_align_left space1 padding3">
# 							<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/1d.png" alt="GV-N4070WF3OC-12GD Video Card">
# 						</div>
# 					</div>
# 				</div>
# 			</div>
#
#
# 		</div>
#
#
# 		<div class="a_plus_module space3 padding3">
# 			<div class="a_plus_info width1 txt_align_center">
# 				<h3 class="a_plus_title text3">
# 					The Ultimate Platform for Gamers and Creators
# 				</h3>
# 				<h3 class="a_plus_title text1">
# 					Powered by GeForce RTX 40 Series and DLSS 3
# 				</h3>
# 			</div>
# 		</div>
#
#
# 		<div class="a_plus_group">
# 			<div class="a_plus_cell col-6">
# 				<div class="a_plus_module">
# 					<div class="txt_align_right">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-6">
# 				<div class="a_plus_module">
# 					<div class="a_plus_info">
# 						<h3 class="a_plus_title text3">
# 							New Streaming Multiprocessors
# 						</h3>
# 						<p>Up to 2x performance and power efficiency</p>
# 						<h3 class="a_plus_title text3 space1">
# 							Fourth-Gen Tensor Cores
# 						</h3>
# 						<p>Up to 4x performance with DLSS 3 vs. brute-force rendering</p>
# 						<h3 class="a_plus_title text3 space1">
# 							Third-Gen RT Cores
# 						</h3>
# 						<p>Up to 2x ray tracing performance</p>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
# 		<div class="a_plus_group">
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a1.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							Cutting-Edge GPUs
# 						</h3>
# 						<p>NVIDIA Ada Lovelace architecture</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a2.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							Realistic and Immersive Graphics
# 						</h3>
# 						<p>Dedicated Ray Tracing Cores</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a3.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							AI-Accelerated Performance
# 						</h3>
# 						<p>NVIDIA DLSS 3</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a4.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							Game-Winning Responsiveness
# 						</h3>
# 						<p>NVIDIA Reflex low-latency platform</p>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
# 		<div class="a_plus_group">
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a5.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							Built for Live Streaming
# 						</h3>
# 						<p>NVIDIA Encoder</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a6.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							AI-Enhanced Voice and Video
# 						</h3>
# 						<p>NVIDIA Broadcast app</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a7.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							Fast-Track Your Creativity
# 						</h3>
# 						<p>NVIDIA Studio</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-3">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2a8.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text3">
# 							Performance and Reliability
# 						</h3>
# 						<p>Game Ready and Studio Drivers</p>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
#
# 		<div class="a_plus_module space1 padding2">
# 			<div class="a_plus_info width1 txt_align_center">
# 				<h3 class="a_plus_title text3">
# 					Ray Tracing
# 				</h3>
# 				<h3 class="a_plus_title text1">
# 					Hyperrealistic. Hyperfast.
# 				</h3>
# 				<p>The Ada architecture unleashes the full glory of ray tracing, which simulates how light behaves in the real world. With the power of RTX 40 Series and third-gen RT Cores, you can experience incredibly detailed virtual worlds like never before.</p>
# 			</div>
# 		</div>
#
# 		<div class="a_plus_module space1">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2b.jpg" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 		</div>
#
#
#
# 		<div class="a_plus_module space1 padding2">
# 			<div class="a_plus_info width1 txt_align_center">
# 				<h3 class="a_plus_title text3">
# 					NVIDIA DLSS 3
# 				</h3>
# 				<h3 class="a_plus_title text1">
# 					The performance multiplier, powered by AI.
# 				</h3>
# 				<p>DLSS is a revolutionary breakthrough in AI-powered graphics that massively boosts performance. Powered by the new fourth-gen Tensor Cores and Optical Flow Accelerator on GeForce RTX 40 Series GPUs, DLSS 3 uses AI to create additional high-quality frames.</p>
# 			</div>
# 		</div>
#
# 		<div class="a_plus_module space1">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2c.jpg" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 		</div>
#
#
#
#
# 		<div class="a_plus_module space1 padding2">
# 			<div class="a_plus_info width1 txt_align_center">
# 				<h3 class="a_plus_title text3">
# 					NVIDIA REFLEX
# 				</h3>
# 				<h3 class="a_plus_title text1">
# 					Victory measured in milliseconds.
# 				</h3>
# 				<p>NVIDIA Reflex and GeForce RTX 40 Series GPUs deliver the lowest latency and best responsiveness for the ultimate competitive advantage. Built to optimize and measure system latency, Reflex provides faster target acquisition, quicker reaction times, and the best aim precision for competitive games.</p>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="a_plus_module space1">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2d.jpg" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 		</div>
#
#
#
# 		<div class="a_plus_module space1 padding2">
# 			<div class="a_plus_info width1 txt_align_center">
# 				<h3 class="a_plus_title text3">
# 					NVIDIA Studio
# 				</h3>
# 				<h3 class="a_plus_title text1">
# 					Your ideas, accelerated by NVIDIA Studio.
# 				</h3>
# 				<p>Take your creative projects to the next level with NVIDIA Studio. Powered by new dedicated hardware, RTX 40 Series unlocks unmatched performance in 3D rendering, video editing, and graphic design. Experience feature-rich RTX accelerations in top creative apps, world-class NVIDIA Studio drivers engineered to provide maximum stability, and a suite of exclusive tools that harness the power of RTX for AI-assisted creative workflows.</p>
# 			</div>
# 		</div>
#
#
#
#
#
# 		<div class="a_plus_module space1">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/2e.jpg" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 		</div>
#
#
# 		<div class="a_plus_module space3 padding3">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/3a.JPG" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 			<div class="a_plus_info position2">
# 				<h3 class="a_plus_title text1">
# 					WINDFORCE COOLING SYSTEM
# 				</h3>
# ...
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text2">
# 							3D ACTIVE FAN
# 						</h3>
# 						<p>The 3D Active Fan provides semi-passive cooling, and the fans will remain off when the GPU is in a low load or low power game.</p>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
# 		<div class="a_plus_group">
# 			<div class="a_plus_cell col-6">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/3d.JPG" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text2">
# 							UNIQUE BLADE FAN
# 						</h3>
# 						<p>The airflow is spilt by the triangular fan edge, and guided smoothly through the 3D stripe curve on the fan surface.</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-6">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/3e.JPG" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text2">
# 							GRAPHENE NANO LUBRICANT
# 						</h3>
# 						<p>Graphene nano lubricant can extend the life of sleeve bearing fan by 2.1 times, close to the life of double ball bearing, and is quieter.</p>
# 					</div>
# 				</div>
# 			</div>
# 		</div>
#
#
# 		<div class="a_plus_group">
# 			<div class="a_plus_cell col-6">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/3f.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text2">
# 							SCREEN COOLING
# 						</h3>
# 						<p>Extended heatsink allows air to pass through, providing better heat dissipation.</p>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="a_plus_cell col-6">
# 				<div class="a_plus_module">
# 					<div class="a_plus_img">
# 						<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/3g.png" alt="GV-N4070WF3OC-12GD Video Card">
# 					</div>
# 					<div class="a_plus_info txt_align_center">
# 						<h3 class="a_plus_title text2">
# 							HEAT PIPES DIRECT TOUCH
# 						</h3>
# 						<p>The shape of the pure copper heat pipe maximizes the direct contact area with the GPU. The heat pipe also covers the VRAM through a large metal plate contact to ensure proper cooling.</p>
# 					</div>
# 				</div>
# 			</div>
#
#
# 		</div>
#
#
#
#
#
#
#
#
# 		<div class="bg2">
#
# 			<div class="a_plus_module space3">
# 				<div class="a_plus_info width1 txt_align_center">
# 					<h3 class="a_plus_title text1">
# 						EXCELLENT IN ESSENTIAL
# 					</h3>
# 				</div>
# 			</div>
#
# 			<div class="a_plus_module space1">
# 				<div class="a_plus_img">
# 					<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/4.png" alt="GV-N4070WF3OC-12GD Video Card">
# 				</div>
# 			</div>
#
# 			<div class="a_plus_module space1">
# 				<div class="a_plus_info width1 txt_align_center">
# 					<h3 class="a_plus_title text2">
# 						PROTECTION METAL BACK PLATE
# 					</h3>
# 					 <p>The metal back plate not only provides an aesthetical shape, but also enhances the structure of the graphics card to provide complete protection.</p>
# 				</div>
# 			</div>
#
# 		<br>
#
#
# 		<div class="bgcolor2 space3 padding3">
#
# 			<div class="a_plus_module space3">
# 				<div class="a_plus_info txt_align_center">
# 					<h3 class="a_plus_title text1">
# 						BUILT STRONG
# 					</h3>
# 				</div>
# 			</div>
#
# 			<div class="a_plus_group">
# 				<div class="a_plus_cell col-6">
# 					<div class="a_plus_module">
# 						<div class="txt_align_left">
# 							<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/5a.png" alt="GV-N4070WF3OC-12GD Video Card">
# 						</div>
# 						<div class="a_plus_info">
# 							<h3 class="a_plus_title text2">
# 								ULTRA DURABLE
# 							</h3>
# 							<p>Ultra Durable certified highest-grade metal chokes, lower ESR solid capacitors, 2oz copper PCB, and lower RDS(on) MOSFETs, plus over-temperature design to deliver superior performance and longer system life.</p>
# 						</div>
# 					</div>
# 				</div>
# 				<div class="a_plus_cell col-6">
# 					<div class="a_plus_module">
# 						<div class="txt_align_left">
# 							<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/5b.png" alt="GV-N4070WF3OC-12GD Video Card">
# 						</div>
# 						<div class="a_plus_info">
# 							<h3 class="a_plus_title text2">
# 								FRIENDLY PCB DESIGN
# 							</h3>
# 							<p>Fully automated production process ensures top quality of the circuit boards and eliminates sharp protrusions of the solder connectors seen on the conventional PCB surface. This friendly design prevents your hands from getting cut or inadvertently damaging components when making your build.</p>
# 						</div>
# 					</div>
# 				</div>
#
#
# 			</div>
#
# 			</div>
#
# 		</div>
#
# 		<div class="bg3">
#
# 		<div class="a_plus_module space3 padding3">
# 			<div class="a_plus_info width1 txt_align_center">
# 				<h3 class="a_plus_title text1">
# 					GIGABYTE CONTROL CENTER
# 				</h3>
# 				<p>GIGABYTE CONTROL CENTER is a unified software for all GIGABYTE supported products. It provides an intuitive interface that allows users to adjust clock speed, voltage, fan mode and power target in real-time.</p>
# 			</div>
# 		</div>
#
#
# 		<div class="a_plus_module space1">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/6.jpg" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 		</div>
#
#
# 		<div class="a_plus_module space2">
# 			<div class="a_plus_img">
# 				<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/7.jpg" alt="GV-N4070WF3OC-12GD Video Card">
# 			</div>
# 		</div>
#
# 		<div class="txt_align_center space2">
# 			<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/7a.png" alt="GV-N4070WF3OC-12GD Video Card">
# 			<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/7b.png" alt="GV-N4070WF3OC-12GD Video Card">
# 			<img src="//c1.neweggimages.com/BizIntell/item/VGA/Video Card - Nvidia/14-932-611/7c.png" alt="GV-N4070WF3OC-12GD Video Card">
# 		</div>
#
#
#
# 		<div class="a_plus_module space3 padding3 padding3b">
# 			<div class="a_plus_info width1">
# 				<div class="has_note">
# 					Notes:
# 				</div>
# 				<p class="note_detail">© 2023 NVIDIA Corporation. NVIDIA, the NVIDIA logo, GeForce, GeForce Experience, GeForce RTX, G-SYNC, and ShadowPlay are registered trademarks and/or trademarks of NVIDIA Corporation in the United States and other countries. All other trademarks and copyrights are the property of their respective owners.</p>
# 				<p class="note_detail">* All the images in this page are for illustration only.</p>
# 			</div>
# 		</div>
#
# 		</div>
#
#    </article>
# </div><li>This item is covered by Newegg.ca&#x27;s Replacement Only Return Policy. <a href="https://kb.newegg.ca/Article/Index/12/2?id=1183#10080" class="link-text" target="_blank" title="Return Policy (new window)">Read full return policy for details.</a></li></ul></div></div><div class="info-cell"><div class="info-item"><h4>Manufacturer Contact Info</h4><ul><li><a href="https://www.gigabyte.com/" rel="noopener noreferrer" target="_blank" class="link-text" title="Manufacturer Product Page (new window)">Manufacturer Product Page</a></li><li><a href="https://www.gigabyte.com/" rel="noopener noreferrer" target="_blank" class="link-text" title="View Manufacturer Website (new window)">Manufacturer Website</a></li><li>Support Phone: <!-- -->1-626-854-9338</li><li><a href="https://www.gigabyte.com/Support/Graphics-Card" rel="noopener noreferrer" target="_blank" class="link-text" title="Support Website (new window)">Support Website</a></li><li><a href="https://www.newegg.ca/GIGABYTE/BrandStore/ID-1314" class="link-text">View other products from <!-- -->GIGABYTE</a></li></ul></div></div></div><div><div class="loader"><span class="fa fa-spinner fa-spin"></span>LOADING...</div></div></div><div class="loader"><i class="fa fa-spinner fa-spin"></i>LOADING...</div></div></div></div></div></div></div></div></div><footer id="Page_Footer_Full" class="footer2021 page-section"><div class="page-section bg-lightgrayblue"><div class="page-content-inner"><div class="grid gap-20px  col-w-3 col-w-s-2"><div class="grid-col radius-m bg-white col-wide subscribe-box"><form target="newsletterSubscribe" method="post" action="https://secure.newegg.ca/notifications/api/newslettersubscribe?Action=Manage&amp;source=Footer" name="Newsletter"><div class="subscribe-box-inner"><div class="section-title"><div class="section-title-text font-xl no-margin-left">Deals Just For You</div></div><p class="font-l"><strong>Sign up to receive exclusive offers in your inbox.</strong></p><div class="input-group"><div class="input-text has-clear auto-flex"><i class="input-text-icon ico ico-envelope text-gray font-xl" aria-label="email"></i><input type="text" placeholder="Enter your e-mail address" aria-label="Enter your e-mail address" name="LoginName" value="" maxLength="128"/><i class="input-text-clear ico ico-times"><span class="display-none">clear text</span></i></div><button type="button" class="button bg-blue">Sign up</button></div><p><a class="link-more text-blue" href="https://promotions.newegg.ca/neemail/latest/index-landing.html" title=""><span>View Latest Email Deals</span> <i class="ico ico-angle-right" aria-label="more"></i></a></p><input type="hidden" value="1" name="Subscribe"/></div></form><iframe id="newsletterSubscribe" name="newsletterSubscribe" style="display:none"></iframe><div class="subscribe-box-bg radius-m"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/Illus_Subscription@4x.png" width="1068" height="672" alt="subscribe"/></div></div><div class="grid-col radius-m bg-white our-apps"><div class="section-title"><div class="section-title-text font-xl">Download Our APP</div></div><div class="our-apps-combine"><a href="https://k9r54.app.goo.gl/desktoppagefooter" class="our-apps-qrcode" target="_blank"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/qrcodes/QRCode-APP.png" width="200" height="200" alt="Shop on Newegg APP"/></a><div class="our-apps-combine-info"><p><strong>Scan the QR code to download App</strong></p><p>Scan this code with your phone&#x27;s camera.</p></div></div><div class="our-apps-bg"><img src="https://c1.neweggimages.com/WebResource/Themes/Nest/bgs/bg_our_app.png" width="250" height="250" alt="Newegg apps screenshot"/></div></div></div></div></div><nav class="footer2021-sitemap bg-darkblue"><div class="page-content-inner"><div class="grid gap-20px col-w-5 col-w-s-1"><div class="grid-col"><div class="footer2021-sitemap-list "><div class="footer2021-sitemap-title">Customer Service</div><ul><li><a class="font-s"  ...
# (function (timediff) {
#   window.__SITE__.var8eec7bc4.calcTimediff = function (cont) {
#     if (window.__SITE__.var8eec7bc4.timediff) cont(window.__SITE__.var8eec7bc4.timediff);
#     else if (!isNaN(timediff)) {
#       window.__SITE__.var8eec7bc4.timediff = timediff;
#       cont(timediff);
#     } else {
#       jQuery.get({
#         url: '/d/dynamic-js/product/Product/CAN/initial-json?op=time',
#         cache: false,
#         dataType: 'text',
#         timeout: 60000,
#         success: function(_1, _2, xhr) {
#           var date = xhr.getResponseHeader('date');
#           var diff = window.__SITE__.var8eec7bc4.timediff = date ? new Date(date) - Date.now() : 0;
#           try { sessionStorage.eggtimediff = diff; } catch(e) {}
#           cont(diff);
#         },
#         error: function () { cont (0); }
#       });
#     }
#   };
# })(parseInt((function(){ try { return sessionStorage.eggtimediff; } catch(e) { return undefined; } })()));
# </script><script defer="">window.__initialState__ = {"Breadcrumbs":[{"Name":"Components & Storage","NValue":100006520,"DepaId":-1,"StoreId":1,"StoreType":4,"Tid":6520,"IsDefault":true},{"Name":"GPUs & Video Graphics Devices","NValue":100006663,"DepaId":-1,"StoreId":38,"StoreType":1,"Tid":6663,"IsDefault":true},{"Name":"GPUs \u002F Video Graphics Cards","NValue":100007708,"DepaId":-1,"StoreId":48,"StoreType":2,"Tid":7708,"IsDefault":true}],"PropertyCollection":{"PropertyGroups":[{"GroupCode":40957,"GroupDescription":"Edition","Style":"Swatch","HasPriceAdditionInfo":false,"SelectedProperty":{"Value":1355595,"Description":"WINDFORCE OC 12G","DisplayInfo":"WINDFORCE OC 12G","ItemImageName":null},"Properties":[{"Value":1374506,"Description":"AERO OC V2 12G","DisplayInfo":"AERO OC V2 12G","ItemImageName":null},{"Value":1374507,"Description":"GAMING OC V2 12G","DisplayInfo":"GAMING OC V2 12G","ItemImageName":null},{"Value":1355595,"Description":"WINDFORCE OC 12G","DisplayInfo":"WINDFORCE OC 12G","ItemImageName":null}],"ShowItemImage":false}],"AvailableFullPaths":[{"ItemNumber":"14-932-684","UrlKeywords":"gigabyte-gv-n4070aero-ocv2-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x","Path":"1374506","IsActivated":true},{"ItemNumber":"14-932-685","UrlKeywords":"gigabyte-geforce-rtx-4070-gv-n4070gaming-ocv2-12gd","Path":"1374507","IsActivated":true},{"ItemNumber":"14-932-611","UrlKeywords":"gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x","Path":"1355595","IsActivated":true}]},"SocialMediaContent":null,"GiftCardStyleList":null,"FlowerSetting":null,"IsShowAutoParts":false,"SponsoredItems":null,"PackageOptions":null,"IsShowBestSellersLink":true,"IsShowLowestPriceLink":true,"IsShowDealsLink":true,"FamilyTree":{"Item":"14-932-683","ParentItem":null,"UnitCost":829.99,"InstantRebateAmount":0,"OwnerCost":0,"OEMMark":"false","Instock":true,"MapPrice":0,"Description":{"Title":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","IMDescription":"VGA GB|GV-N407SWF3OC-12GD R","BulletDescription":"Powered by GeForce RTX 4070 SUPER\r\nIntegrated with 12GB GDDR6X 192-bit memory interface\r\nWINDFORCE cooling system\r\nGraphene nano lubricant\r\nProtection metal back plate","LineDescription":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","WebDescription":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","LongDescription":null,"UrlKeywords":"gigabyte-windforce-gv-n407swf3oc-12gd-nvidia-geforce-rtx-4070-super-12gb-gddr6x","ShortTitle":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","WHIDescription":null,"ProductName":"GIGABYTE WINDFORCE GeForce RTX 4070 SUPER 12GB","ManualProductName":"GIGABYTE WINDFORCE GeForce RTX 4070 SUPER 12GB","SimplifiedWebDescription":"","SimplifiedLineDescription":"GIGABYTE GeForce RTX 4070 SUPER 12G Gaming PC","SimplifiedBulletinDescription":""},"Review":{"Rating":4,"HumanRating":82,"CombineGroup":3,"ReviewSign":"","ReviewSignValue":null,"ViewCount":0,"ItemAsDescribedRate":null,"DeliverdOnTimeRate":null,"SatisfiedServiiceRate":null,"PositiveReviewRate":null,"ImageVideoReviews":12,"RatingOneDecimal":4.4,"DeliverdOnTimeRateLast12M":null,"ItemAsDescribedRateLast12M":null,"SatisfiedServiiceRateLast12M":null,"PositiveReviewRateLast12M":null},"NewImage":{"ImageNameList":"14-932-683-11.jpg,14-932-683-09.jpg,14-932-683-13.jpg,14-932-683-14.jpg,14-932-683-12.jpg,14-932-683-15.jpg,14-932-683-16.jpg,14-932-683-10.jpg","ImageName":"14-932-683-11.jpg","DFIS360ImgFlag":null,"NobgImageName":null},"Feature":{"IsAIT":false,"IsRestricted":false,"IsPremier":false,"IsFirstFromAsia":false,"IsInPMCC":false,"IsHot":false,"IsFreshDeal":false,"HasManufacturerWarranty":false,"ShipByNewegg":true ...

# %%
 doc = BeautifulSoup(results.text,"html.parser")

 print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html class="show-tab-store" lang="en-ca">
#  <head>
#   <title>
#    GIGABYTE NVIDIA GeForce RTX 4070 Overclock Gaming 12GB WINDFORCE GDDR6X PCI Express 4.0 ATX Graphics Card GV-N4070WF3 OC -12GD - Newegg - Newegg.ca
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="always" name="referrer"/>
#   <meta content="Newegg, Newegg.ca, GIGABYTE WINDFORCE GeForce RTX 4070 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4070WF3OC-12GD" name="keywords"/>
#   <meta content="Get GIGABYTE GeForce RTX 4070 WINDFORCE Overclock edition, featuring 12GB GDDR6X memory, PCI Express 4.0 and superior cooling. Order today at Newegg." name="description"/>
#   <meta content="https://c1.neweggimages.com/ProductImage/14-932-611-V01.jpg" property="og:image"/>
#   <meta content="Buy GIGABYTE WINDFORCE GeForce RTX 4070 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4070WF3OC-12GD with fast shipping and top-rated customer service. Once you know, you Newegg!" property="og:description"/>
#   <meta content="GIGABYTE NVIDIA GeForce RTX 4070 Overclock Gaming 12GB WINDFORCE GDDR6X PCI Express 4.0 ATX Graphics Card GV-N4070WF3 OC -12GD - Newegg - Newegg.com" property="og:title"/>
#   <meta content="https://www.newegg.ca/gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x/p/N82E16814932611" property="og:url"/>
#   <meta content="website" property="og:type"/>
#   <meta content="english" name="language"/>
#   <meta content="© 2000-2024 Newegg Inc." name="copyright"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="index,follow,max-image-preview:large,max-snippet:-1" name="robots"/>
#   <meta content="on" name="X-DNS-Prefetch-Control"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link href="https://c1.neweggimages.com/WebResource/ngm/newegg.ico" rel="shortcut icon" type="image/x-icon"/>
#   <link href="https://www.newegg.ca/gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x/p/N82E16814932611" rel="canonical"/>
#   <link href="https://www.newegg.ca/amp/gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x/p/N82E16814932611" rel="amphtml"/>
#   <link crossorigin="" href="https://c1.neweggimages.com/" rel="preconnect"/>
#   <link crossorigin="" href="https://imk.neweggimages.com/" rel="preconnect"/>
#   <script type="text/javascript">
#    !function(){try{if(!navigator.userAgent.match(/Newegg.+App/ig))return;var e=document.createElement("style");e.innerText="html.sticky-header-top body{padding-top: 0px!important;}header{display: none;}footer{display: none;}",document.querySelector("head").append(e)}catch(t){console.log(t)}}();
#   </script>
#   <script>
#    window.__PolyfillScripts__={"core-js":"https://c1.neweggimages.com/WebResource/Scripts/WWW/core-js.polyfill.min.js","intersection-observer":"https://c1.neweggimages.com/WebResource/Scripts/WWW/intersection-observer.polyfill.min.js"}
#   </script>
#   <script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/runtime~product~ProductDetail-ae2c5243.js">
#   </script>
#   <script src="https://c1.neweggimages.com/WebResource/Scripts/WWW/polyfillEntry-a43910b7.js">
#   </script>
#   <link href="https://c1.neweggimages.com/WebResource/Themes/WWW/CSS/ProductDetail-1063e43d35.css" rel="stylesheet"/>
#   <script id="kimoi" type="application/json">
#    [{"type":"setCookie","payload":{"cookie":"CountryRegion","value":"CAN"}},{"type":"setCookie","payload":{"cookie":"LanguageCode","value":"en"}},{"type":"setSubCookie","payload":{"cookie":"CountryConfiguration","subCookieKey":"CurrencyCode","subCookieValue":"CAD"}}]
#   </script>
#   <script>
#    (window.BOOMR_mq=window.BOOMR_mq||[]).push(["addVar",{"rua.upush":"false","rua.cpush":"false","rua.upre":"false","rua.cpre":"false","rua.uprl":"false","rua.cprl":"false","rua.cprf":"false","rua.trans":"","rua.cook":"false","rua.ims":"false","rua.ufprl":"false","rua.cfprl":"false","rua.isuxp":"false","rua.texp":"norulematch"}]);
#   </script>
#   <script>
#    !function(e){var n="https://s.go-mpulse.net/boomerang/";if("False"=="True")e.BOOMR_config=e.BOOMR_config||{},e.BOOMR_config.PageParams=e.BOOMR_config.PageParams||{},e.BOOMR_config.PageParams.pci=!0,n="https://s2.go-mpulse.net/boomerang/";if(window.BOOMR_API_key="VVKLK-DW65Z-X2EAR-S9CNF-C36HD",function(){function e(){if(!o){var e=document.createElement("script");e.id="boomr-scr-as",e.src=window.BOOMR.url,e.async=!0,i.parentNode.appendChild(e),o=!0}}function t(e){o=!0;var n,t,a,r,d=document,O=window;if(window.BOOMR.snippetMethod=e?"if":"i",t=function(e,n){var t=d.createElement("script");t.id=n||"boomr-if-as",t.src=window.BOOMR.url,BOOMR_lstart=(new Date).getTime(),e=e||d.body,e.appendChild(t)},!window.addEventListener&&window.attachEvent&&navigator.userAgent.match(/MSIE [67]\./))return window.BOOMR.snippetMethod="s",void t(i.parentNode,"boomr-async");a=document.createElement("IFRAME"),a.src="about:blank",a.title="",a.role="presentation",a.loading="eager",r=(a.frameElement||a).style,r.width=0,r.height=0,r.border=0,r.display="none",i.parentNode.appendChild(a);try{O=a.contentWindow,d=O.document.open()}catch(_){n=document.domain,a.src="javascript:var d=document.open();d.domain='"+n+"';void(0);",O=a.contentWindow,d=O.document.open()}if(n)d._boomrl=function(){this.domain=n,t()},d.write("<bo"+"dy onload='document._boomrl();'>");else if(O._boomrl=function(){t()},O.addEventListener)O.addEventListener("load",O._boomrl,!1);else if(O.attachEvent)O.attachEvent("onload",O._boomrl);d.close()}function a(e){window.BOOMR_onload=e&&e.timeStamp||(new Date).getTime()}if(!window.BOOMR||!window.BOOMR.version&&!window.BOOMR.snippetExecuted){window.BOOMR=window.BOOMR||{},window.BOOMR.snippetStart=(new Date).getTime(),window.BOOMR.snippetExecuted=!0,window.BOOMR.snippetVersion=12,window.BOOMR.url=n+"VVKLK-DW65Z-X2EAR-S9CNF-C36HD";var i=document.currentScript||document.getElementsByTagName("script")[0],o=!1,r=document.createElement("link");if(r.relList&&"function"==typeof r.relList.supports&&r.relList.supports("preload")&&"as"in r)window.BOOMR.snippetMethod="p",r.href=window.BOOMR.url,r.rel="preload",r.as="script",r.addEventListener("load",e),r.addEventListener("error",function(){t(!0)}),setTimeout(function(){if(!o)t(!0)},3e3),BOOMR_lstart=(new Date).getTime(),i.parentNode.appendChild(r);else t(!1);if(window.addEventListener)window.addEventListener("load",a,!1);else if(window.attachEvent)window.attachEvent("onload",a)}}(),"".length>0)if(e&&"performance"in e&&e.performance&&"function"==typeof e.performance.setResourceTimingBufferSize)e.performance.setResourceTimingBufferSize();!function(){if(BOOMR=e.BOOMR||{},BOOMR.plugins=BOOMR.plugins||{},!BOOMR.plugins.AK){var n=""=="true"?1:0,t="",a="ejbyjvqx3suvazv3rqoq-f-31eb6b97a-clientnsv4-s.akamaihd.net",i="false"=="true"?2:1,o={"ak.v":"37","ak.cp":"639580","ak.ai":parseInt("275154",10),"ak.ol":"0","ak.cr":35,"ak.ipv":4,"ak.proto":"http/1.1","ak.rid":"100883eb","ak.r":47480,"ak.a2":n,"ak.m":"x","ak.n":"essl","ak.bpcip":"34.67.132.0","ak.cport":46482,"ak.gh":"23.32.237.169","ak.quicv":"","ak.tlsv":"tls1.3","ak.0rtt":"","ak.csrc":"-","ak.acc":"bbr","ak.t":"1723567133","ak.ak":"hOBiQwZUYzCg5VSAfCLimQ==...","ak.pv":"95","ak.dpoabenc":"","ak.tf":i};if(""!==t)o["ak.ruds"]=t;var r={i:!1,av:function(n){var t="http.initiator";if(n&&(!n[t]||"spa_hard"===n[t]))o["ak.feo"]=void 0!==e.aFeoApplied?1:0,BOOMR.addVar(o)},rv:function(){var e=["ak.bpcip","ak.cport","ak.cr","ak.csrc","ak.gh","ak.ipv","ak.m","ak.n","ak.ol","ak.proto","ak.quicv","ak.tlsv","ak.0rtt","ak.r","ak.acc","ak.t","ak.tf"];BOOMR.removeVar(e)}};BOOMR.plugins.AK={akVars:o,akDNSPreFetchDomain:a,init:function(){if(!r.i){var e=BOOMR.subscribe;e("before_beacon",r.av,null,null),e("onbeacon",r.rv,null,null),r.i=!0}return this},is_complete:function(){return!0}}}}()}(window);
#   </script>
#  </head>
#  <body>
#   <div>
#    <script type="text/javascript">
#     ;;;(function(){var e=document.querySelector('meta[name="viewport"]'),t=document.createElement("meta");t.name="viewport",t.content="width=device-width",e||document.head.appendChild(t)})();
#    </script>
#   </div>
#   <div>
#    <script src="https://c1.neweggimages.com/webresource/Scripts/Others/MarketingChannel/processmktchannelv5.js">
#    </script>
#   </div>
#   <div>
#    <script type="text/javascript">
#     var nebs=nebs||{};nebs.errors=[];window.onerror=function(){nebs.errors.push(arguments);return true;}
#    </script>
#   </div>
#   <div>
#    <script src="https://c1.neweggimages.com/webResource/Scripts/WWW/jquery-3.5.1.min.js">
#    </script>
#   </div>
#   <div>
#    <script>
#     !function(){var style = document.createElement('style');style.type = 'text/css';style.innerHTML=document.getElementById('NewTemplate')?'div.grid-col.radius-m.bg-white.our-apps > div.line-horizontal.bg-line.width-auto > span{color:#4D4D4D}.sticky-header-top body{padding-top:115px;height:auto;min-height:calc(100% - 115px);} .sticky-header-top .page-content{padding-top:0;min-height:0;}':'@import url(https://c1.neweggimages.com/webresource/themes/darkmode-min.28.css);.dark-mode #ot-sdk-btn.ot-sdk-show-settings, .dark-mode #ot-sdk-btn.optanon-show-settings{ color: #e3e3e3 !important }.dark-mode #ot-sdk-btn.ot-sdk-show-settings:hover, .dark-mode #ot-sdk-btn.optanon-show-settings:hover{color: #ea9d28 !important;};.footer2021-disclaimer-link:hover {color: #e3e3e3!important;} div.grid-col.radius-m.bg-white.our-apps > div.line-horizontal.bg-line.width-auto > span{color:#4D4D4D}.dark-mode .item-img{opacity: 1 !important;} '; document.getElementsByTagName('head').item(0).appendChild(style); }()
#    </script>
#   </div>
#   <div>
#    <script type="text/javascript">
#     (function(){var darkv = document.cookie.match('(^|;) ?NV_Theme=([^;]*)(;|$)');var dark = darkv ? darkv[2] : "false";if (dark == "true") {if(!document.getElementById('NewTemplate')){jQuery('html').addClass('dark-mode');}else{document.documentElement.classList.add("dark-mode")}}var style = document.createElement("style");var darkCss='#Dark_Mode{display:none;}.header2021-toggle{z-index:5}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:20px}.header2021-toggle:hover{transform:scale(1)}.header2021-toggle:hover .bg-lightgray{background-color:rgba(235,235,235,1)}.header2021-toggle .toggle-body{border:1px solid #212121;border-radius:30px}.header2021-toggle .toggle-body-inner:after{border-radius:30px;width:30px;top:0;bottom:0;margin-left:-1px;box-shadow:0 1px 6px 0 rgb(0 0 0 / 16%)}.header2021-toggle .toggle-handle{font-size:20px;color:#474747}.header2021-toggle .dark-mode-tooltip{padding:5px 15px;white-space:nowrap}.header2021-toggle.menu.at-bottom .menu-body{left:auto;right:0;margin-top:12px;text-align:left}.header2021-toggle.at-bottom>.menu-arrow{left:auto;right:20px;text-align:left}.header2021-toggle.at-bottom>.menu-body>.menu-arrow{left:auto!important;right:20px}.dark-mode .header2021-toggle .toggle-handle.take-on{padding-left:8px}.dark-mode .header2021-toggle:hover .bg-lightgray{background-color:#ea7421}.dark-mode .header2021-toggle .toggle-body{border:1px solid #835b38}.dark-mode .header2021-toggle .bg-lightgray{background-color:#e05d00}.dark-mode .header2021-toggle input[type="checkbox"]:checked ~ .toggle-body .toggle-body-inner:after{margin-right:0;margin-left:0;top:0}.dark-mode .header2021-toggle .toggle-body-inner:after{box-shadow:0 6px 6px 0 rgb(0 0 0 / 16%)}@media(max-width:599px){.header2021-inner{padding:15px 2px}.header2021-logo{width:60px}.header2021-country.header2021-nav:not(:first-child){margin-left:15px}.header2021-toggle .bg-lightgray{background:#fff}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:15px}.header2021-toggle .toggle-body{min-width:30px;height:30px;border-radius:50%}.header2021-toggle .toggle-body-inner{width:100%;height:100%;transform:translateX(0);justify-content:center;align-items:center}.header2021-toggle .toggle-handle{height:100%;line-height:1.1;padding:0;font-size:22px;justify-content:center;z-index:2}.header2021-toggle .toggle-body-inner:after{content:none}.header2021-toggle .toggle-handle.take-off{padding:0}.header2021-toggle .toggle-handle.take-on,.header2021-toggle.menu.at-bottom .menu-body{display:none}.dark-mode .header2021-toggle .toggle-handle.take-on{display:flex;padding:0}.dark-mode .header2021-toggle .toggle-handle.take-off{display:none}.section-right>.line-vertical-new{margin:0 0 0 10px}}@media(max-width:350px){.header2021-nav-inner,.header2021-nav.menu .header2021-nav-inner{padding-left:26px;height:26px;min-height:26px}.header2021-country-flag{width:26px;height:26px}.header2021-nav-icon{width:26px;height:26px;line-height:26px;font-size:24px;top:2px}.header2021-nav ~ .header2021-nav{margin-left:5px}.header2021-nav ~ .header2021-nav.header2021-toggle{margin-left:10px}.header2021-toggle .toggle-body{min-width:24px;height:24px}.header2021-toggle .toggle-handle{font-size:16px}}';try{style.appendChild(document.createTextNode(darkCss));}catch(ex){style.styleSheet.cssText = darkCss;}var head = document.getElementsByTagName("head")[0];head&&head.appendChild(style);var darkbut = jQuery('<div class="header2021-nav header2021-toggle toggle toggle-m menu at-bottom"><label id="darkLabel"><input type="checkbox" id="checkdarkmode"><span class="toggle-body bg-lightgray font-l"><span class="toggle-body-inner"><span class="toggle-handle take-on">&#9790;</span><span class="toggle-handle take-off ">&#9728;</span></span></span></label><div id="darkModal" class="menu-body bg-white radius-s shadow-level-1"><i class="menu-arrow"></i><p class="dark-mode-tooltip">Switch to Dark Mode</p></div></div>');jQuery(document).ready(function (){jQuery('.header2021-country').after(dark ...
#    </script>
#   </div>
#   <div>
#    <script type="text/javascript">
#     ;;; (function () { var ADRPattern = /Newegg.+Android.+App/ig; var IPNPattern = /Newegg.+(iPhone|iPad).+App/ig; var Container = { APP: 'GTM-TF5LHJ5', EGG: 'GTM-WJ2PC5C' }; function LoadContainer(w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://imk.neweggimages.com/webresource/scripts/gatra/lib/app/neggtm.js?negg=2&id=' + i + dl; f.parentNode.insertBefore(j, f); }; if (navigator.userAgent.match(ADRPattern) || navigator.userAgent.match(IPNPattern)) { LoadContainer(window, document, 'script', 'dataLayer', Container.APP); } else { } })();
#    </script>
#   </div>
#   <div>
#    <script type="text/javascript">
#     ;;; (function () { var ADRPattern = /Newegg.+Android.+App/ig; var IPNPattern = /Newegg.+(iPhone|iPad).+App/ig; var Container = { APP: 'GTM-TF5LHJ5', EGG: 'GTM-W26F4QT' }; function LoadContainer(w, d, s, l, i) { w[l] = w[l] || []; w[l].push({ 'gtm.start': new Date().getTime(), event: 'gtm.js' }); var f = d.getElementsByTagName(s)[0], j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src = 'https://imk.neweggimages.com/webresource/scripts/gatra/lib/can/neggtm.js?negg=2&id=' + i + dl; f.parentNode.insertBefore(j, f); }; if (navigator.userAgent.match(ADRPattern) || navigator.userAgent.match(IPNPattern)) {  } else { LoadContainer(window, document, 'script', 'dataLayer', Container.EGG); } })();
#    </script>
#   </div>
#   <div>
#    <script type="text/javascript">
#     ;(function () {var s = document.createElement("script");
#   s.defer=true;
#  s.type = "text/javascript";
#    s.src = "//imk.neweggimages.com/webresource/scripts/plugin/inhousebiztra.js";
#  var node = document.getElementsByTagName("script")[0];
#  node.parentNode.insertBefore(s, node);})();
#    </script>
#   </div>
#   <div>
#    <style>
#     @import url(https://c1.neweggimages.com/webresource/themes/WWW/CSS/fixManufactory.css)
#    </style>
#   </div>
#   <div>
#    <script defer="" src="https://c1.neweggimages.com/webresource/Scripts/Others/TopRatedSeller/new-feature-script.2.0.5.min.js" type="text/javascript">
#    </script>
#   </div>
#   <div>
#    <script defer="" src="https://c1.neweggimages.com/webresource/Scripts/Others/ShippingEstimate/shippingestimate-v.7.1.min.js" type="text/javascript">
#    </script>
#   </div>
#   <div>
#    <script type="text/javascript">
#     ;;;(function() {
#       window.__ga_biItems=[{pages: ["all"],events:["view_item","select_item","view_item_list"],property:["item_range","spa","best_seller","lowest_price","deal_type","boost_type"]}];    window.__ga_forbiddenList = [{
#  pages: ["all"],
#   events:["recommendation_module_click","search_ahead_view","legacy_view","legacy_click","view_item_list","recommendation_module_view","spa_view","spa_click","search_ahead_click","infocard_view","infocard_click","web_notification_view","trending_keywords_view","select_item"],
#   clearGa4: true,
#   clearInhouse:false,
#       }
#    ];
#                 window.__ga_mappingAdobe = [{
#    events:["event63"],
#    eventName:"legacy_click",
#    mapping:{
#   legacy_element_value:"evar78",
#  module_name:"evar79",
#    products:"products"
#     }
#    },{
#    events:["event168"],
#    eventName:"legacy_view",
#    mapping:{
#   legacy_element_value:"evar78",
#    products:"products"
#     }
#    },{
#  events: ["event21"],
#  eventname: "email_subscribed",
#  mapping:{
#  }
#  }, {
#  events: ["event40"],
#  eventname: "modules_click", mapping:{
#  module_name: "eVar103"
#  }
#  }, {
#  events: ["event91"],
#  eventname: "modules_view", mapping:{
#  module_name: "eVar79"
#  }
#  }];
#                 window.__ga_linkInternalFilters = "javascript:,newegg.com,gamecrate.com,abs.com,checkout.us.zip.co,zip.co,checkout.quadpay.com,3debspay.boc.cn,alfabank.ru,arcot.com,billmelater.com,citibank.co.kr,ftpsllc.com,garanti.com.tr,hyundaicard.com,kbcard.com,keb.co.kr,masterpass.com,mycardsecure.com,newegg3.com.sh,paypal.com,samsungcard.co.kr,secure2gw.ro,securecode.com,secureserver.net,securesuite.co.uk,securesuite.net,shinhancard.com,verifiedbyvisa.com,visa.com,visa.com.ar,web.v.me,secondfunnel.com,cardinalcommerce.com,secure.neweggbusiness.com,www-newegg-com.cdn.ampproject.org,www.newegg.ca,secure.newegg.ca,kb.neweggbusiness.com,www.neweggbusiness.com,help.newegg.ca,secure.m.newegg.ca,secure.newegg.com,www.rosewill.com,neweggbusiness.com,sellerportal.newegg.cn,partner.gqc.newegg.space,help.neweggbusiness.com,secure.newegg6.com.sh,sellerportal62780.gqc.newegg.space,central3.newegg.org,partner.newegg.cn,secure.newegg4.com.sh,newegg.io,newegggpu.com,justgpu.com";
#             })()
#    </script>
#   </div>
#   <div>
#    <style>
#     .eggpoints-product-buying .eggpoints-icon{width: 45px; height: 22px; background-position: -276px -41px}.eggpoints-product-buying{margin-bottom: 10px;}
#    </style>
#   </div>
#   <div>
#    <script>
#     jQuery(document).ready(function () {jQuery(".form-option-item-price").map(function(){var saving = jQuery(this).find("span").text();if(saving){jQuery(this).parent().addClass("has-price");jQuery(this).parent().append('<div class="form-deals-list"><div class="form-tag-deals"><span>'+saving+'</span></div></div>');jQuery(this).find("span").remove();}});});
#    </script>
#   </div>
#   <div>
#    <style>
#     .product-wrap .product-options .form-option-item.is-color {padding: 5px 9px;} .widget-box #Revolving {width: 32px !important; min-width: 32px !important;}.product-wrap .product-options .form-option-item { border: 1px solid #D1D1D1; padding: 5px 9px;}.price-financing-divider.text-left span{display:none}.product-wrap .product-similar-links {align-items: flex-start;}.product-wrap .product-similar-link {align-items: flex-start;max-width: none;}.product-wrap .product-similar-link .product-similar-content {display: block;min-width: 92px;}.product-wrap .product-similar-link.is-see-more {max-width: none;}.product-wrap .product-similar-link.is-see-more .product-similar-content { min-width: 70px;}.product-wrap .product-similar-link .link-more:hover {white-space: normal; -webkit-line-clamp: unset; max-height: none;}
#    </style>
#   </div>
#   <div>
#    <script type="text/javascript">
#     !function(){const e=new URLSearchParams(window.location.search),t=e.get("ranMID"),n=e.get("ranSiteID");if(t&&n){const e=new Date,o=e.getUTCFullYear(),r=String(e.getUTCMonth()+1).padStart(2,"0"),i=String(e.getUTCDate()).padStart(2,"0"),s=String(e.getUTCHours()).padStart(2,"0"),d=String(e.getUTCMinutes()).padStart(2,"0"),c=`${o}${r}${i}_${s}${d}`,u=encodeURIComponent("amid:"+t+"|ald:"+c+"|atrv:"+n),l=new Date;l.setDate(l.getDate()+180);const a=l.toUTCString(),p=window.location.hostname.split('.'),h=p.slice(-2).join('.'),m=h.startsWith('localhost')?'localhost':'.'+h;document.cookie="rmStoreGateway="+u+"; expires="+a+"; path=/; domain="+m+"; secure; SameSite=Lax"}}();
#    </script>
#   </div>
#   <div>
#    <script defer="" src="https://c1.neweggimages.com/webresource/Scripts/Others/RequestQuote/requestQuote-v6.0.js" type="text/javascript">
#    </script>
#   </div>
#   <div>
#    <style>
#     .header2021 .page-content-inner{max-width: inherit !important;}
#    </style>
#   </div>
#   <div>
#    <style>
#     #trendingBanner_776938,#trendingBanner_776939,#trendingBanner_717831,#trendingBanner_623096,#trendingBanner_776940,#trendingBanner_776941,#trendingBanner_776942,#trendingBanner_776943,#trendingBanner_776944,#trendingBanner_776945,#trendingBanner_776946,#trendingBanner_774658,#trendingBanner_755812{color:#c63527;} .dark-mode #trendingBanner_776938,.dark-mode #trendingBanner_717831,.dark-mode #trendingBanner_623096,.dark-mode #trendingBanner_776939,.dark-mode #trendingBanner_776940,.dark-mode #trendingBanner_776941,.dark-mode #trendingBanner_776942,.dark-mode #trendingBanner_776943,.dark-mode #trendingBanner_776944,.dark-mode #trendingBanner_776945,.dark-mode #trendingBanner_776946,.dark-mode #trendingBanner_774658,.dark-mode #trendingBanner_755812{color:#FFD700;}
#    </style>
#   </div>
#   <div>
#    <style>
#     .modal-intermediary .squaretrade-banner img{width:inherit;}.modal-intermediary .squaretrade-wrap{width:inherit;}
#    </style>
#   </div>
#   <div>
#    <style>
#     .header2021-user-bar{background:#eee}.header2021-user-bar::before{background:none}.header2021-account.menu.at-bottom>.menu-body.bg-white>.header2021-user-bar~.menu-arrow::before{border-bottom-color:#eee}.header2021-user-bar > .menu-list{right: 10px;position: absolute;}
#    </style>
#   </div>
#   <div>
#    <script>
#     jQuery(document).ready(function(){jQuery("div.product-highlights h2").html("Performance <sup style='color:red;font-weight:bold'>Beta</sup>");var addtrackingonclick=function(){window?.__ga_push({event: 'legacy_click',legacy_element_value: 'product-highlights-impression'});jQuery("#product_highlights_swiper .swiper-button-next, #product_highlights_swiper .swiper-button-prev, #product_highlights_swiper div.product-highlights-tips,.product-highlights a").off("click",addtrackingonclick)};jQuery("#product_highlights_swiper .swiper-button-next, #product_highlights_swiper .swiper-button-prev, #product_highlights_swiper div.product-highlights-tips, .product-highlights a").on("click",addtrackingonclick);if([3742,10,3365,32].indexOf(__initialState__.ItemDetail.Subcategory.SubcategoryId)>-1){jQuery('head').append('<style>#ProductViewSticky > div > div.product-reviews-bytes{display:none;}</style>');}});
#    </script>
#   </div>
#   <div>
#    <script defer="" src="https://c1.neweggimages.com/webresource/Scripts/Others/DynamicComboAvailable_v0.1.js" type="text/javascript">
#    </script>
#   </div>
#   <div>
#    <style>
#     #modal-intermediary .squaretrade-image>img{width: inherit;max-height: 180px;max-width: 240px;margin: auto;}#modal-intermediary .squaretrade-logo>img{height:60px;}#modal-intermediary .squaretrade-logo{margin-bottom:0px;}#modal-intermediary .adpopup-injected{padding-bottom: 0px !important;}#modal-intermediary .modal-intermediary-list{border:none;margin-top:0px;}#modal-intermediary .squaretrade-wrap.fix{margin:0 auto;}
#    </style>
#   </div>
#   <div>
#    <script>
#     jQuery(document).ready(function () {if(__initialState__.ItemDetail.EnergyStar){switch(__initialState__.ItemDetail.EnergyStar.EnergyStarTypeID){case 10:jQuery("div.product-wrap > div.product-energy-guide > a > img").attr("src", "https://c1.neweggimages.com/webresource/themes/2005/Nest/pdf.png").attr("alt", "user manual");jQuery("div.product-wrap > div.product-energy-guide > a > span").text("View User Manual Details");jQuery("div.product-wrap > div.product-energy-guide > a").attr("href","https://c1.neweggimages.com/IMAttachment/UserManual/"+__initialState__.ItemDetail.EnergyStar.EnergyStarFileName);break;case 11:jQuery("div.product-wrap > div.product-energy-guide > a > img").attr("src", "https://c1.neweggimages.com/webresource/themes/2005/Nest/data sheet.png").attr("alt", "data sheet");jQuery("div.product-wrap > div.product-energy-guide > a > span").text("View Data Sheet Details");jQuery("div.product-wrap > div.product-energy-guide > a").attr("href","https://c1.neweggimages.com/IMAttachment/Datasheet/"+__initialState__.ItemDetail.EnergyStar.EnergyStarFileName);break;}}})
#    </script>
#   </div>
#   <div>
#    <style>
#     .item-img>img,.goods-img>img{object-fit: contain}
#    </style>
#   </div>
#   <div>
#    <style>
#     #Buy_Together[class="tab-box product-combo-box"] .tab-content .row-body { width: 100% !important; padding: 0; } #Buy_Together[class="tab-box product-combo-box"] .row-body-inner .swiper-container { margin: 0; } #Buy_Together[class="tab-box product-combo-box"] .tab-tags { margin-left: 0px !important; } #Buy_Together[class="tab-box product-combo-box"] .product-buy-combo { display: none; } #Buy_Together[class="tab-box product-combo-box"] .swiper-box .row.has-side-left > .row-side { display: none; } #Buy_Together[class="tab-box product-combo-box"] .swiper-box { padding: 20px 20px 0 20px; } #Buy_Together[class="tab-box product-combo-box"] .tab-panes .swiper-box-arrow-next { right: -25px; } #Buy_Together[class="tab-box product-combo-box"] .tab-panes .swiper-box-arrow-prev { left: -25px; } #Buy_Together[class="tab-box product-combo-box"] .row-body .row-body-inner { padding: 0; } #Buy_Together[class="tab-box product-combo-box"] .multiple-choice-card, #Buy_Together[class="tab-box product-combo-box"] .multiple-choice-card:hover, #Buy_Together[class="tab-box product-combo-box"] .multiple-choice-card.is-checked { border: 0px; }#Buy_Together[class="tab-box product-combo-box"] .tab-content .swiper-wrapper .item-img { margin: 0 auto; }
#    </style>
#    <script>
#     jQuery(document).ready(function () { var subc = [20, 3743, 514, 32, 3090, 233, 3365, 10]; if (document.getElementById("newProductPageContent")) { if (subc.indexOf(__initialState__.ItemDetail.Subcategory.SubcategoryId) > -1) { var observer = new MutationObserver(function (mutations) { mutations.forEach(function (mutation) { if (document.querySelector(".product-contents .product-similar-box")) { jQuery(".product-contents .page-section").prepend(jQuery(".product-contents .product-combo-up")); jQuery("#product-details").after(jQuery(".product-contents .product-similar-box")); observer.disconnect(); } }); }); observer.observe(document.querySelector(".product-contents .page-section"), { childList: true }); } } else { var handleBuyTogether = () => { function handleClick(event) { const clickedElement = event.target.closest(".swiper-slide"); if (clickedElement) { var id = jQuery(clickedElement) .find(".item-container .item-stock") .attr("id") .replace(/stock_/g, ""); jQuery(clickedElement).find(".item-container .item-stock").attr("id", ""); location.href = "/p/" + id; } } jQuery("#Buy_Together .tab-content .swiper-wrapper").off("click"); jQuery("#Buy_Together .tab-content .swiper-wrapper").on("click", handleClick); jQuery("#Buy_Together .tab-content .swiper-wrapper .btn-quickview").remove(); jQuery("#Buy_Together .tab-content .swiper-wrapper .multiple-choice-check").remove(); jQuery("#Buy_Together .tab-content .swiper-wrapper ul.form-cells").remove(); if (subc.indexOf(__initialState__.ItemDetail.Subcategory.SubcategoryId) > -1) { var relatedtitle = jQuery("#Buy_Together") .siblings() .filter(function () { return this.innerText.toUpperCase() == "PRODUCTS RELATED TO THIS ITEM"; }); var relateddom = jQuery("#Buy_Together"); if (relatedtitle.length > 0) { jQuery("#PDP_product-recommend").after(relateddom); jQuery("#PDP_product-recommend").after(relatedtitle); } }var observer = new MutationObserver(function (mutations) { mutations.forEach(function (mutation) { if (mutation.target.classList.contains("swiper-container-initialized")) { jQuery("#Buy_Together .tab-content .swiper-wrapper").off("click"); jQuery("#Buy_Together .tab-content .swiper-wrapper").on("click", handleClick); jQuery("#Buy_Together .tab-content .swiper-wrapper .btn-quickview").remove(); jQuery("#Buy_Together .tab-content .swiper-wrapper .multiple-choice-check").remove(); jQuery("#Buy_Together .tab-content .swiper-wrapper ul.form-cells").remove(); } }); }); observer.observe(document.getElementById("Buy_Together"), { subtree: true, childList: true }); };function handleSimilarProduct(withCombotabs) { var similar = jQuery("#recommend_modules_swiper_similar_0").parent(); var similartitle = jQuery("#PDP_product-recommend") .siblings(".swiper-box-top") .filter(function () { return this.innerText.toLowerCase() == "similar products"; }); jQuery("#product-details").after('<div class="tab-box"><div id="new-similar-position" class="tab-panes similar_box"></div></div>'); jQuery("#new-similar-position").append(similar); jQuery(similar).show(); jQuery(similartitle).remove(); jQuery("#product-details").after('<div class="swiper-box-top"><h2 class="swiper-box-top-title">Similar Products</h2></div>'); if(withCombotabs){ jQuery("#PDP_Combo_product-recommend .tab-navs").remove(); jQuery("#product-recommend h2").text("Combos"); jQuery("#PDP_Combo_product-recommend .tab-panes .tab-pane").show(); } }var observer = new MutationObserver((mutationsList, observer) => { for (let mutation of mutationsList) { if (mutation.type === "childList") { var target = jQuery("#recommend_modules_swiper_similar_0"); if (target.length > 0) { observer.disconnect(); target = jQuery("#Buy_Together"); if (target.length > 0 && !target.attr("updated_style") && !__initialState__?.DynamicCombo) { target.attr("updated_style", "true"); handleBuyTogether(); } target = jQuery("#PDP_Combo_product-recommend"); if (target.length > 0 && !target.attr("updated_style") ) { if(subc.indexOf(__initialState__.ItemDetail.Subcategory.Sub ...
#    </script>
#   </div>
#   <div id="app">
#    <header class="header2021 bg-white">
#     <div class="page-content-inner">
#      <div class="header2021-inner">
#       <div class="section-left auto-flex">
#        <div class="header2021-logo">
#         <a class="header2021-logo-img" href="https://www.newegg.ca/" title="Newegg.ca - Computer Parts, Laptops, Electronics, HDTVs, Digital Cameras and More!">
#          <img alt="Newegg" height="150" src="https://c1.neweggimages.com/WebResource/Themes/Nest/logos/Newegg_full_color_logo_RGB.SVG" width="297"/>
#         </a>
#        </div>
#        <div class="header2021-nav header2021-location menu at-bottom">
#         <a class="header2021-nav-inner bg-transparent-gray" href="#" title="Select address ">
#          <i aria-label="icon of my location" class="ico ico-map-marker header2021-nav-icon">
#          </i>
#          <div class="header2021-nav-title text-gray font-s">
#           Hello
#           <!-- -->
#           <span class="header2021-info-nowrap header2021-info-min">
#           </span>
#          </div>
#          <div class="header2021-nav-subtitle">
#           <span class="">
#            Select address
#           </span>
#           <span>
#           </span>
#          </div>
#         </a>
#        </div>
#        <div class="header2021-search auto-flex">
#         <div class="header2021-search-inner">
#          <div class="header2021-search-box auto-flex">
#           <input autocomplete="off" title="Search Site" type="search" value=""/>
#          </div>
#          <div class="header2021-search-button">
#           <button aria-label="Search" class="ico ico-search">
#            <span class="display-none">
#             Search
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="section-right">
#        <div class="header2021-nav header2021-country menu at-bottom">
#         <a class="header2021-country-flag bg-transparent-gray" title="Change Country">
#          <i class="flag ca">
#          </i>
#          <span class="display-none">
#           Change Country
#          </span>
#         </a>
#        </div>
#        <div class="nav-complex">
#         <a class="header2021-nav-inner bg-transparent-gray" href="https://secure.newegg.ca/login/signin?nextpage=" title="My Account">
#          <i aria-label="icon of my account" class="ico ico-user header2021-nav-icon">
#          </i>
#         </a>
#        </div>
#        <div class="header2021-nav header2021-returns s-hide">
#         <a class="header2021-nav-inner bg-transparent-gray" href="https://secure.newegg.ca/orders/list" title="Orders">
#          <div class="header2021-nav-title text-gray font-s">
#           <span>
#            Returns
#           </span>
#          </div>
#          <div class="header2021-nav-subtitle">
#           &amp; Orders
#          </div>
#         </a>
#        </div>
#        <div class="header2021-nav header2021-cart">
#         <a aria-label="Shopping Cart" class="header2021-nav-inner bg-transparent-gray" href="https://secure.newegg.ca/shop/cart" title="Shopping Cart">
#          <i aria-label="icon of shopping cart" class="ico ico-shopping-cart header2021-nav-icon">
#          </i>
#         </a>
#        </div>
#       </div>
#      </div>
#      <div class="header2021-inner has-hamburger">
#       <div class="header2021-hamburger-new header2021-hamburger menu at-bottom bg-transparent-gray">
#        <div class="display-flex align-items-center">
#         <i aria-label="Site Menu" class="header2021-hamburger-icon ico ico-bars">
#         </i>
#         <span class="header2021-hamburger-text">
#          Menu
#          <i class="ico ico-caret-left-solid">
#          </i>
#         </span>
#        </div>
#       </div>
#       <div aria-label="decoration" class="line-vertical bg-line">
#       </div>
#       <div class="section-left auto-flex">
#        <div class="header2021-portals" id="Portals_swiper">
#         <div class="swiper-container swiper-container-horizontal">
#          <div class="swiper-wrapper">
#           <div class="swiper-slide">
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/todays-deals?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Today%27s+Best+Deals&amp;icid=748680" id="trendingBanner_748680" title="Today's Best Deals">
#             <span class="font-s">
#              Today's Best Deals
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/p/pl?N=4812&amp;cm_sp=Head_Navigation-_-Under_Search_Bar-_-Combo+Deals&amp;icid=770031" id="trendingBanner_770031" title="Combo Deals">
#             <span class="font-s">
#              Combo Deals
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/Clearance-Store/EventSaleStore/ID-697?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Clearance+Deals&amp;icid=776002" id="trendingBanner_776002" title="Clearance Deals">
#             <span class="font-s">
#              Clearance Deals
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/d/best-sellers?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Best+Sellers&amp;icid=623097" id="trendingBanner_623097" title="Best Sellers">
#             <span class="font-s">
#              Best Sellers
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/Spotlight/Store/ID-14?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Spotlight&amp;icid=726849" id="trendingBanner_726849" title="Spotlight">
#             <span class="font-s">
#              Spotlight
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/Elite-Deals/EventSaleStore/ID-779?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Elite+Deals&amp;icid=649302" id="trendingBanner_649302" title="Elite Deals">
#             <span class="font-s">
#              Elite Deals
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/tools/custom-pc-builder?cm_sp=Head_Navigation-_-Under_Search_Bar-_-PC+Builder&amp;icid=623096" id="trendingBanner_623096" title="PC Builder">
#             <span class="font-s">
#              PC Builder
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/sellers/?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Sell+on+Newegg&amp;icid=646148" id="trendingBanner_646148" title="Sell on Newegg">
#             <span class="font-s">
#              Sell on Newegg
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/tools/gaming-pc-finder?cm_sp=Head_Navigation-_-Under_Search_Bar-_-Gaming+PC+Finder&amp;icid=717831" id="trendingBanner_717831" title="Gaming PC Finder">
#             <span class="font-s">
#              Gaming PC Finder
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/tools/nas-builder?cm_sp=Head_Navigation-_-Under_Search_Bar-_-NAS+Builder&amp;icid=747225" id="trendingBanner_747225" title="NAS Builder">
#             <span class="font-s">
#              NAS Builder
#             </span>
#            </a>
#           </div>
#           <div class="swiper-slide">
#            <a "="" class="header2021-portal" href="//www.newegg.ca/asus-nuc-configurator?cm_sp=Head_Navigation-_-Under_Search_Bar-_-ASUS+NUC+Configurator&amp;icid=776914" id="trendingBanner_776914" title="ASUS NUC Configurator">
#             <span class="font-s">
#              ASUS NUC Configurator
#             </span>
#            </a>
#           </div>
#          </div>
#          <div class="swiper-scrollbar">
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="section-right header2021-links">
#        <a class="header2021-link font-s" href="https://www.newegg.ca/promotions/nepro/18-1552/index.html?utm_medium=newegg&amp;utm_source=newegg-home&amp;cm_mmc=ref-newegg-_-newegg-home-_-na-_-na" target="_blank" title="Newegg Business">
#         <span class="header2021-b2b-newegg">
#          Newegg
#         </span>
#         <span class="header2021-b2b-business">
#          Business
#         </span>
#        </a>
#        <div aria-label="decoration" class="line-vertical bg-line">
#        </div>
#        <a class="button button-s bg-blue" id="newegg_footer_feedback" rel="noopener noreferrer" style="cursor:pointer" title="Feedback">
#         <i class="ico ico-comment-alt-smile">
#         </i>
#         <span>
#          Feedback
#         </span>
#        </a>
#        <div aria-label="decoration" class="line-vertical bg-line">
#        </div>
#        <a class="button button-s bg-blue" href="https://kb.newegg.ca" title="Help Center">
#         <i class="ico ico-question-circle">
#         </i>
#         <span>
#          Help Center
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#     <div class="header2021-portals-menu menu-body bg-white shadow-level-1" id="BrowsingHistory_menu">
#      <div class="page-content-inner">
#       <div class="section-title">
#        <div class="section-title-text font-l">
#         Your Browsing History
#        </div>
#       </div>
#       <div class="history-timeline">
#        <div class="loading">
#         <i class="ico ico-spinner ico-spin">
#         </i>
#        </div>
#       </div>
#      </div>
#     </div>
#    </header>
#    <div>
#    </div>
#    <div class="nav-x-body-top-bar-wrap">
#     <div class="nav-x-body-top-bar fix">
#      <ol class="breadcrumb">
#       <li>
#        <a href="https://www.newegg.ca/" title="Home">
#         Home
#        </a>
#       </li>
#       <li class="">
#        <a href="https://www.newegg.ca/Components-Storage/Store/ID-1" title="Components &amp; Storage">
#         Components &amp; Storage
#        </a>
#       </li>
#       <li class="">
#        <a href="https://www.newegg.ca/GPUs-Video-Graphics-Devices/Category/ID-38" title="GPUs &amp; Video Graphics Devices">
#         GPUs &amp; Video Graphics Devices
#        </a>
#       </li>
#       <li class="">
#        <a href="https://www.newegg.ca/GPUs-Video-Graphics-Cards/SubCategory/ID-48" title="GPUs / Video Graphics Cards">
#         GPUs / Video Graphics Cards
#        </a>
#       </li>
#       <li class="">
#        <a href="https://www.newegg.ca/GIGABYTE-GPUs-Video-Graphics-Cards/BrandSubCat/ID-1314-48" title="GIGABYTE">
#         GIGABYTE
#        </a>
#       </li>
#       <li class="is-current">
#        Item#:
#        <em>
#         N82E16814932611
#        </em>
#       </li>
#      </ol>
#     </div>
#     <script type="application/ld+json">
#      {"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.newegg.ca/","name":"Home"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.newegg.ca/Components-Storage/Store/ID-1","name":"Components & Storage"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.newegg.ca/GPUs-Video-Graphics-Devices/Category/ID-38","name":"GPUs & Video Graphics Devices"}},{"@type":"ListItem","position":4,"item":{"@id":"https://www.newegg.ca/GPUs-Video-Graphics-Cards/SubCategory/ID-48","name":"GPUs / Video Graphics Cards"}},{"@type":"ListItem","position":5,"item":{"@id":"https://www.newegg.ca/GIGABYTE-GPUs-Video-Graphics-Cards/BrandSubCat/ID-1314-48","name":"GIGABYTE"}}]}
#     </script>
#    </div>
#    <div class="page-content">
#     <div class="page-section">
#      <div class="page-section-inner">
#       <div class="row is-product has-side-right has-side-items">
#        <div class="row-side">
#         <div class="product-buy-box is-product-blackfriday-first">
#          <div class="product-pane">
#           <div class="product-price">
#            <ul class="price">
#             <li class="price-was">
#              <span class="price-was-data">
#               $809.99
#              </span>
#             </li>
#             <li class="price-map">
#             </li>
#             <li class="price-current">
#              <span class="price-current-label">
#              </span>
#              $
#              <strong>
#               749
#              </strong>
#              <sup>
#               .99
#              </sup>
#             </li>
#             <li class="price-save">
#              <span class="price-save-label">
#               Save:
#              </span>
#              <span class="price-save-dollar">
#               <span>
#                $60.00
#               </span>
#               <span>
#               </span>
#              </span>
#              <span class="price-save-percent">
#               (7%)
#              </span>
#             </li>
#             <li class="price-note" style="font-size:14px">
#              <span class="price-note-dollar">
#               <span class="price-current">
#               </span>
#              </span>
#              <span class="price-note-label">
#              </span>
#              <span class="price-note-dollar">
#              </span>
#              <span class="price-note-label">
#              </span>
#             </li>
#             <li class="price-financing-block" id="affirmlidivider" style="height:16px">
#             </li>
#             <li class="price-financing-block" id="quadpaylidivider" style="height:16px">
#             </li>
#             <li class="price-ship">
#             </li>
#            </ul>
#            <div class="product-subscribe">
#            </div>
#           </div>
#          </div>
#          <div class="product-buy" id="ProductBuy">
#           <div class="nav-row">
#            <div class="nav-col has-qty-box">
#             <div class="qty-box">
#              <input aria-label="Qty" class="qty-box-input" maxlength="3" type="text" value="1"/>
#              <button class="qty-box-plus fas fa-plus" type="button">
#               <span class="hid-text">
#                plus
#               </span>
#              </button>
#              <button class="qty-box-minus fas fa-minus" type="button">
#               <span class="hid-text">
#                minus
#               </span>
#              </button>
#              <span class="form-error-message">
#               Limit 1 per customer.
#              </span>
#             </div>
#            </div>
#            <div class="nav-col">
#             <button class="btn btn-primary btn-wide" title="Add GIGABYTE WINDFORCE GeForce RTX 4070 12GB GDDR6X PCI Express 4.0 x16 ATX Video Card GV-N4070WF3OC-12GD to cart">
#              Add to cart
#              <i class="fas fa-caret-right">
#              </i>
#             </button>
#            </div>
#           </div>
#          </div>
#          <div class="product-seller-new" style="min-height:69px">
#          </div>
#          <div class="product-info-group">
#           <div class="product-ship-info">
#            <div class="product-ship-from">
#             Ships from Canada.
#            </div>
#           </div>
#          </div>
#          <div class="product-btn-group">
#           <div class="product-btn product-alert">
#            <div class="btn has-icon-left fa-bell">
#             Price Alert
#            </div>
#           </div>
#           <div class="product-btn product-wishlist">
#            <a class="btn has-icon-left fa-heart-outline">
#             Add To List
#            </a>
#            <span>
#             Found on
#             <strong>
#              682
#             </strong>
#             wish list
#             <!-- -->
#             s
#            </span>
#           </div>
#          </div>
#          <div class="product-seller no-border-bottom">
#           <div class="product-shipping">
#            Shipped by:
#            <a href="https://kb.newegg.com/knowledge-base/shipped-by-newegg/">
#             <strong>
#              Newegg
#             </strong>
#            </a>
#           </div>
#           <div class="product-shipping">
#            Sold by:
#            <strong>
#             Newegg
#            </strong>
#           </div>
#          </div>
#         </div>
#         <div class="product-similar-links">
#          <div class="product-similar-link is-see-more">
#           <div class="product-similar-icon">
#            <i class="ico ico-search-long">
#            </i>
#           </div>
#           <div class="product-similar-content">
#            <span>
#             See more
#            </span>
#            <a class="link-more" href="https://www.newegg.ca/p/pl?d=rtx+4070" target="_blank">
#             rtx 4070
#            </a>
#           </div>
#          </div>
#          <div class="product-similar-link">
#           <div class="product-similar-icon">
#            <i class="ico ico-trophy-alt">
#            </i>
#           </div>
#           <div class="product-similar-content">
#            <span>
#             Best sellers of
#            </span>
#            <a class="link-more" href="https://www.newegg.ca/d/Best-Sellers/GPUs-Video-Graphics-Cards/s/ID-48?cm_sp=best-seller-_-from-pdpmorelink" target="_blank">
#             GPUs / Video Graphics Cards
#            </a>
#           </div>
#          </div>
#          <div class="product-similar-link">
#           <div class="product-similar-icon">
#            <i class="ico ico-circle-dollar-light">
#            </i>
#           </div>
#           <div class="product-similar-content">
#            <span>
#             Lowest price of
#            </span>
#            <a class="link-more" href="https://www.newegg.ca/d/Lowest-Price-In-30-Days/GPUs-Video-Graphics-Cards/s/ID-48?cm_sp=l30d-_-from-pdpmorelink" target="_blank">
#             GPUs / Video Graphics Cards
#            </a>
#           </div>
#          </div>
#          <div class="product-similar-link is-deals">
# ...
#          Privacy Policy
#         </a>
#        </div>
#        <div style="margin-bottom:20px">
#         © 2000-
#         <!-- -->
#         2024
#         <!-- -->
#         Newegg Inc
#         <span id="ieFontCheck" style="width:0">
#          A
#         </span>
#         s used herein, “Newegg.ca” means Newegg Canada Inc. unless the context specifically refers to the
#         <a class="footer2021-disclaimer-link" href="//www.newegg.ca" style="margin-right:0">
#          www.newegg.ca
#         </a>
#         web address.
#        </div>
#        <ul class="social-icons">
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-facebook-f" href="https://facebook.com/NeweggCanada" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            Facebook
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-twitter" href="https://twitter.com/neweggcan" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            Twitter
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-instagram" href="https://www.instagram.com/newegg/" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            Instagram
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-linkedin-in" href="https://www.linkedin.com/company/newegg-com" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            LinkedIn
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-pinterest" href="https://www.pinterest.com/newegg/" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            Pinterest
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-youtube" href="https://www.youtube.com/user/newegg" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            YouTube
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-twitch" href="https://www.twitch.tv/newegg" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            Twitch
#           </span>
#          </a>
#         </li>
#         <li class="social-icon bg-darkblue">
#          <a class="ico ico-discord" href="https://discordapp.com/invite/newegg" rel="noopener noreferrer" target="_blank">
#           <span class="display-none">
#            Discord
#           </span>
#          </a>
#         </li>
#         <li class="social-icon ico-tiktok-img">
#          <style>
#           .ico-tiktok-img { background-image: url(https://c1.neweggimages.com/webresource/themes/Nest/icons/tiktok_light.png);}.dark-mode .ico-tiktok-img { background-image: url(https://c1.neweggimages.com/webresource/themes/Nest/icons/tiktok_dark.png);}
#          </style>
#          <a class="ico" href="https://www.tiktok.com/@newegg" style="width: 24px;height: 24px;display: block;" target="_blank">
#           <span class="display-none">
#            TikToc
#           </span>
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <div class="floating-right-tools">
#      <div class="compare-items-improvement compare-items-new">
#       <div aria-hidden="true" aria-label="compare-items-toolbar" class="compare-items-toolbar toolbar-wrap toolbar-ani-top">
#        <div class="page-content-inner">
#         <div class="compare-items-content display-flex align-items-center">
#          <div class="compare-items-side display-flex">
#           <div class="compare-items-button">
#            <div class="section-subtitle">
#             <div class="section-subtitle-text">
#              Compare Items
#             </div>
#            </div>
#            <i aria-label="arrow icon" class="ico ico-caret-left-solid xs-show">
#            </i>
#           </div>
#          </div>
#          <div class="compare-items-swiper-wrapper">
#           <div class="compare-items-swiper swiper-container">
#            <div class="swiper-wrapper slabs-body">
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                1
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                2
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                3
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                4
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                5
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                6
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                7
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                8
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                9
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                10
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                11
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                12
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                13
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                14
#               </span>
#              </div>
#             </div>
#             <div class="swiper-slide swiper-slide slab">
#              <div class="slab-inner">
#               <span class="compare-tips-text font-s">
#                15
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="swiper-button-prev swiper-button-black">
#            </div>
#            <div class="swiper-button-next swiper-button-black">
#            </div>
#           </div>
#          </div>
#          <div class="display-flex justify-content-center flex-direction-column goods-button-group">
#           <button class="button button-m bg-blue" type="button">
#            <span>
#             COMPARE
#            </span>
#           </button>
#           <button class="button button-m button-clear-all" type="button">
#            <span>
#             Clear All
#            </span>
#           </button>
#          </div>
#         </div>
#        </div>
#        <div class="compare-items-close xs-hide">
#         <i aria-label="arrow icon" class="ico ico-angle-down">
#         </i>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="Messages-pop-content bg-white radius-m false" id="Messages-pop-content">
#      <div class="Messages-pop-content-title font-l">
#       Messages
#      </div>
#      <i class="Messages-close ico ico-times">
#      </i>
#      <div class="Messages-nav">
#       <div class="Messages-nav-space">
#       </div>
#      </div>
#     </div>
#    </footer>
#   </div>
#   <script src="/d/dynamic-js/product/Product/CAN/initial-json">
#   </script>
#   <script>
#    window.__SITE__ || document.write("<script src='/dynamic-js/product/Product/CAN/initial-json'>\x3C/script>")
#   </script>
#   <script>
#    (function (timediff) {
#   window.__SITE__.var8eec7bc4.calcTimediff = function (cont) {
#     if (window.__SITE__.var8eec7bc4.timediff) cont(window.__SITE__.var8eec7bc4.timediff);
#     else if (!isNaN(timediff)) {
#       window.__SITE__.var8eec7bc4.timediff = timediff;
#       cont(timediff);
#     } else {
#       jQuery.get({
#         url: '/d/dynamic-js/product/Product/CAN/initial-json?op=time',
#         cache: false,
#         dataType: 'text',
#         timeout: 60000,
#         success: function(_1, _2, xhr) {
#           var date = xhr.getResponseHeader('date');
#           var diff = window.__SITE__.var8eec7bc4.timediff = date ? new Date(date) - Date.now() : 0;
#           try { sessionStorage.eggtimediff = diff; } catch(e) {}
#           cont(diff);
#         },
#         error: function () { cont (0); }
#       });
#     }
#   };
# })(parseInt((function(){ try { return sessionStorage.eggtimediff; } catch(e) { return undefined; } })()));
#   </script>
#   <script defer="">
#    window.__initialState__ = {"Breadcrumbs":[{"Name":"Components & Storage","NValue":100006520,"DepaId":-1,"StoreId":1,"StoreType":4,"Tid":6520,"IsDefault":true},{"Name":"GPUs & Video Graphics Devices","NValue":100006663,"DepaId":-1,"StoreId":38,"StoreType":1,"Tid":6663,"IsDefault":true},{"Name":"GPUs \u002F Video Graphics Cards","NValue":100007708,"DepaId":-1,"StoreId":48,"StoreType":2,"Tid":7708,"IsDefault":true}],"PropertyCollection":{"PropertyGroups":[{"GroupCode":40957,"GroupDescription":"Edition","Style":"Swatch","HasPriceAdditionInfo":false,"SelectedProperty":{"Value":1355595,"Description":"WINDFORCE OC 12G","DisplayInfo":"WINDFORCE OC 12G","ItemImageName":null},"Properties":[{"Value":1374506,"Description":"AERO OC V2 12G","DisplayInfo":"AERO OC V2 12G","ItemImageName":null},{"Value":1374507,"Description":"GAMING OC V2 12G","DisplayInfo":"GAMING OC V2 12G","ItemImageName":null},{"Value":1355595,"Description":"WINDFORCE OC 12G","DisplayInfo":"WINDFORCE OC 12G","ItemImageName":null}],"ShowItemImage":false}],"AvailableFullPaths":[{"ItemNumber":"14-932-684","UrlKeywords":"gigabyte-gv-n4070aero-ocv2-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x","Path":"1374506","IsActivated":true},{"ItemNumber":"14-932-685","UrlKeywords":"gigabyte-geforce-rtx-4070-gv-n4070gaming-ocv2-12gd","Path":"1374507","IsActivated":true},{"ItemNumber":"14-932-611","UrlKeywords":"gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x","Path":"1355595","IsActivated":true}]},"SocialMediaContent":null,"GiftCardStyleList":null,"FlowerSetting":null,"IsShowAutoParts":false,"SponsoredItems":null,"PackageOptions":null,"IsShowBestSellersLink":true,"IsShowLowestPriceLink":true,"IsShowDealsLink":true,"FamilyTree":{"Item":"14-932-683","ParentItem":null,"UnitCost":829.99,"InstantRebateAmount":0,"OwnerCost":0,"OEMMark":"false","Instock":true,"MapPrice":0,"Description":{"Title":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","IMDescription":"VGA GB|GV-N407SWF3OC-12GD R","BulletDescription":"Powered by GeForce RTX 4070 SUPER\r\nIntegrated with 12GB GDDR6X 192-bit memory interface\r\nWINDFORCE cooling system\r\nGraphene nano lubricant\r\nProtection metal back plate","LineDescription":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","WebDescription":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","LongDescription":null,"UrlKeywords":"gigabyte-windforce-gv-n407swf3oc-12gd-nvidia-geforce-rtx-4070-super-12gb-gddr6x","ShortTitle":"GIGABYTE GeForce RTX 4070 SUPER WINDFORCE OC 12G Graphics Card, 3x WINDFORCE Fans, 12GB 192-bit GDDR6X, GV-N407SWF3OC-12GD  Video Card","WHIDescription":null,"ProductName":"GIGABYTE WINDFORCE GeForce RTX 4070 SUPER 12GB","ManualProductName":"GIGABYTE WINDFORCE GeForce RTX 4070 SUPER 12GB","SimplifiedWebDescription":"","SimplifiedLineDescription":"GIGABYTE GeForce RTX 4070 SUPER 12G Gaming PC","SimplifiedBulletinDescription":""},"Review":{"Rating":4,"HumanRating":82,"CombineGroup":3,"ReviewSign":"","ReviewSignValue":null,"ViewCount":0,"ItemAsDescribedRate":null,"DeliverdOnTimeRate":null,"SatisfiedServiiceRate":null,"PositiveReviewRate":null,"ImageVideoReviews":12,"RatingOneDecimal":4.4,"DeliverdOnTimeRateLast12M":null,"ItemAsDescribedRateLast12M":null,"SatisfiedServiiceRateLast12M":null,"PositiveReviewRateLast12M":null},"NewImage":{"ImageNameList":"14-932-683-11.jpg,14-932-683-09.jpg,14-932-683-13.jpg,14-932-683-14.jpg,14-932-683-12.jpg,14-932-683-15.jpg,14-932-683-16.jpg,14-932-683-10.jpg","ImageName":"14-932-683-11.jpg","DFIS360ImgFlag":null,"NobgImageName":null},"Feature":{"IsAIT":false,"IsRestricted":false,"IsPremier":false,"IsFirstFromAsia":false,"IsInPMCC":false,"IsHot":false,"IsFreshDeal":false,"HasManufacturerWarranty":false,"ShipByNewegg":true,"ShowOEMRetail":true," ...
#   </script>
#   <script defer="">
#    window.__neweggState__ = {"country":{"name":"Canada","alpha2":"ca","alpha3":"CAN","geoLocation":"North America","currency":"CAD"},"user":{"nvtc":"string","contactWith":"string","loginName":"string","accessToken":"string","lastVisitTime":1,"loginId":"string","isEggExpert":true,"loginToken":"string","isPremier":true,"isLogin":true},"domains":{"WWW":"www.newegg.ca","SSL":"secure.newegg.ca","MOBILESSL":"secure.m.newegg.ca","COM":"www.newegg.com","SecureCOM":"secure.newegg.com","CA":"www.newegg.ca","Dynamic":"newegg.com"},"currency":{"extraUnit":"","currencyCode":"CAD","countryCode":"CAN","unit":"$","decimalDigits":2,"groupSizes":3,"decimalSeparator":".","groupSeparator":",","positivePattern":0,"supportDecimal":true}}
#   </script>
#   <script defer="">
#    window.__pageInfo__ = {"params":{"keyword":"gigabyte-windforce-gv-n4070wf3oc-12gd-nvidia-geforce-rtx-4070-12gb-gddr6x","parentItem":"N82E16814932611"},"query":{},"routeName":"Product","isWWWDomain":true,"imageName":"product","hostname":"www.newegg.ca","theme":null}
#   </script>
#   <script defer="">
#    window.__langResouce__ = {}
#   </script>
#   <iframe id="cross_storage_www" src="https://www.newegg.ca/api/storageHub" style="display:none">
#   </iframe>
#   <iframe id="cross_storage_ssl" src="https://secure.newegg.ca/api/storageHub" style="display:none">
#   </iframe>
#   <script defer="" src="https://c1.neweggimages.com/WebResource/Scripts/WWW/vendor~product~ProductDetail-d35b3216.js">
#   </script>
#   <script defer="" src="https://c1.neweggimages.com/WebResource/Scripts/WWW/common~product~ProductDetail-1bfa8539.js">
#   </script>
#   <script defer="" src="https://c1.neweggimages.com/WebResource/Scripts/WWW/ProductDetail-2104af2d.js">
#   </script>
#   <script defer="" src="https://c1.neweggimages.com/WebResource/Scripts/WWW/adapterScript~product~ProductDetail-da6079e7.js">
#   </script>
#  </body>
# </html>

# %%
prices = doc.find_all(text="$")
parent = prices[0].parent
print(parent)
# Out:
# <li class="price-current"><span class="price-current-label"></span>$<strong>749</strong><sup>.99</sup></li>
# <ipython-input-16-e36260a6721a>:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   prices = doc.find_all(text="$")

# %%
strong = parent.strong
print(strong.string)

## alternate way

strong = doc.find('strong')
print(strong.string)
# Out:
# 749
# 749

# %% [markdown]
# ---

# %%
with open('/content/index3.html', 'r') as f:
  doc = BeautifulSoup(f, 'html.parser')

# %%
print(doc.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Educational registration form
#   </title>
#   <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.4.1/css/all.css" integrity="sha384-5sAR7xN1Nv6T6+dT2mhtzEpVJvfS3NScPQTrOxhwjIuvcA67KV2R5Jz6kr4abQsz" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet"/>
#   <style>
#    html, body {
#       min-height: 100%;
#       }
#       body, div, form, input, select, p {
#       padding: 0;
#       margin: 0;
#       outline: none;
#       font-family: Roboto, Arial, sans-serif;
#       font-size: 16px;
#       color: #eee;
#       }
#       body {
#       background: url("/uploads/media/default/0001/01/b5edc1bad4dc8c20291c8394527cb2c5b43ee13c.jpeg") no-repeat center;
#       background-size: cover;
#       }
#       h1, h2 {
#       text-transform: uppercase;
#       font-weight: 400;
#       }
#       h2 {
#       margin: 0 0 0 8px;
#       }
#       .main-block {
#       display: flex;
#       flex-direction: column;
#       justify-content: center;
#       align-items: center;
#       height: 100%;
#       padding: 25px;
#       background: rgba(0, 0, 0, 0.5);
#       }
#       .left-part, form {
#       padding: 25px;
#       }
#       .left-part {
#       text-align: center;
#       }
#       .fa-graduation-cap {
#       font-size: 72px;
#       }
#       form {
#       background: rgba(0, 0, 0, 0.7);
#       }
#       .title {
#       display: flex;
#       align-items: center;
#       margin-bottom: 20px;
#       }
#       .info {
#       display: flex;
#       flex-direction: column;
#       }
#       input, select {
#       padding: 5px;
#       margin-bottom: 30px;
#       background: transparent;
#       border: none;
#       border-bottom: 1px solid #eee;
#       }
#       input::placeholder {
#       color: #eee;
#       }
#       option:focus {
#       border: none;
#       }
#       option {
#       background: black;
#       border: none;
#       }
#       .checkbox input {
#       margin: 0 10px 0 0;
#       vertical-align: middle;
#       }
#       .checkbox a {
#       color: #26a9e0;
#       }
#       .checkbox a:hover {
#       color: #85d6de;
#       }
#       .btn-item, button {
#       padding: 10px 5px;
#       margin-top: 20px;
#       border-radius: 5px;
#       border: none;
#       background: #26a9e0;
#       text-decoration: none;
#       font-size: 15px;
#       font-weight: 400;
#       color: #fff;
#       }
#       .btn-item {
#       display: inline-block;
#       margin: 20px 5px 0;
#       }
#       button {
#       width: 100%;
#       }
#       button:hover, .btn-item:hover {
#       background: #85d6de;
#       }
#       @media (min-width: 568px) {
#       html, body {
#       height: 100%;
#       }
#       .main-block {
#       flex-direction: row;
#       height: calc(100% - 50px);
#       }
#       .left-part, form {
#       flex: 1;
#       height: auto;
#       }
#       }
#   </style>
#  </head>
#  <body>
#   <div class="main-block">
#    <div class="left-part">
#     <i class="fas fa-graduation-cap">
#     </i>
#     <h1>
#      Register to our courses
#     </h1>
#     <p>
#      W3docs provides free learning materials for programming languages like HTML, CSS, Java Script, PHP etc.
#     </p>
#     <div class="btn-group">
#      <a class="btn-item" href="https://www.w3docs.com/learn-html.html">
#       Learn HTML
#      </a>
#      <a class="btn-item" href="https://www.w3docs.com/quiz/#">
#       Select Quiz
#      </a>
#     </div>
#     $2345
#    </div>
#    <form action="/">
#     <div class="title">
#      <i class="fas fa-pencil-alt">
#      </i>
#      <h2>
#       Register here
#      </h2>
#     </div>
#     $123
#     <div class="info">
#      <input class="fname" name="name" placeholder="Full name" type="text"/>
#      <input name="name" placeholder="Email" type="text"/>
#      <input name="name" placeholder="Phone number" type="text"/>
#      <input name="name" placeholder="Password" type="password"/>
#      <select>
#       <option selected="" value="course-type">
#        Course type*
#       </option>
#       <option value="short-courses">
#        Short courses
#       </option>
#       <option value="featured-courses">
#        Featured courses
#       </option>
#       <option value="undergraduate">
#        Undergraduate
#       </option>
#       <option value="diploma">
#        Diploma
#       </option>
#       <option value="certificate">
#        Certificate
#       </option>
#       <option value="masters-degree">
#        Masters degree
#       </option>
#       <option value="postgraduate">
#        Postgraduate
#       </option>
#      </select>
#     </div>
#     <div class="checkbox">
#      <input name="checkbox" type="checkbox"/>
#      <span>
#       I agree to the
#       <a href="https://www.w3docs.com/privacy-policy">
#        Privacy Poalicy for W3Docs.
#       </a>
#      </span>
#     </div>
#     <button href="/" type="submit">
#      Submit
#     </button>
#    </form>
#   </div>
#  </body>
# </html>

# %%
## Access and modify attributes of a tag

tag = doc.find('option')
print(tag)
# Out:
# <option selected="" value="course-type">Course type*</option>

# %%
tag['value'] = 'new-value'
print(tag)
# Out:
# <option selected="" value="new-value">Course type*</option>

# %%
tag['color']='blue'
print(tag)
# Out:
# <option color="blue" selected="" value="new-value">Course type*</option>

# %%
print(tag.attrs)
# Out:
# {'value': 'new-value', 'selected': '', 'color': 'blue'}

# %%
## find multiple tags at the same time

tags = doc.find_all(['p','div', 'li'])
print(tags)
# Out:
# [<div class="main-block">
# <div class="left-part">
# <i class="fas fa-graduation-cap"></i>
# <h1>Register to our courses</h1>
# <p>W3docs provides free learning materials for programming languages like HTML, CSS, Java Script, PHP etc.</p>
# <div class="btn-group">
# <a class="btn-item" href="https://www.w3docs.com/learn-html.html">Learn HTML</a>
# <a class="btn-item" href="https://www.w3docs.com/quiz/#">Select Quiz</a>
# </div>
#         $2345
#       </div>
# <form action="/">
# <div class="title">
# <i class="fas fa-pencil-alt"></i>
# <h2>Register here</h2>
# </div>
#         $123
#         <div class="info">
# <input class="fname" name="name" placeholder="Full name" type="text"/>
# <input name="name" placeholder="Email" type="text"/>
# <input name="name" placeholder="Phone number" type="text"/>
# <input name="name" placeholder="Password" type="password"/>
# <select>
# <option color="blue" selected="" value="new-value">Course type*</option>
# <option value="short-courses">Short courses</option>
# <option value="featured-courses">Featured courses</option>
# <option value="undergraduate">Undergraduate</option>
# <option value="diploma">Diploma</option>
# <option value="certificate">Certificate</option>
# <option value="masters-degree">Masters degree</option>
# <option value="postgraduate">Postgraduate</option>
# </select>
# </div>
# <div class="checkbox">
# <input name="checkbox" type="checkbox"/><span>I agree to the <a href="https://www.w3docs.com/privacy-policy">Privacy Poalicy for W3Docs.</a></span>
# </div>
# <button href="/" type="submit">Submit</button>
# </form>
# </div>, <div class="left-part">
# <i class="fas fa-graduation-cap"></i>
# <h1>Register to our courses</h1>
# <p>W3docs provides free learning materials for programming languages like HTML, CSS, Java Script, PHP etc.</p>
# <div class="btn-group">
# <a class="btn-item" href="https://www.w3docs.com/learn-html.html">Learn HTML</a>
# <a class="btn-item" href="https://www.w3docs.com/quiz/#">Select Quiz</a>
# </div>
#         $2345
#       </div>, <p>W3docs provides free learning materials for programming languages like HTML, CSS, Java Script, PHP etc.</p>, <div class="btn-group">
# <a class="btn-item" href="https://www.w3docs.com/learn-html.html">Learn HTML</a>
# <a class="btn-item" href="https://www.w3docs.com/quiz/#">Select Quiz</a>
# </div>, <div class="title">
# <i class="fas fa-pencil-alt"></i>
# <h2>Register here</h2>
# </div>, <div class="info">
# <input class="fname" name="name" placeholder="Full name" type="text"/>
# <input name="name" placeholder="Email" type="text"/>
# <input name="name" placeholder="Phone number" type="text"/>
# <input name="name" placeholder="Password" type="password"/>
# <select>
# <option color="blue" selected="" value="new-value">Course type*</option>
# <option value="short-courses">Short courses</option>
# <option value="featured-courses">Featured courses</option>
# <option value="undergraduate">Undergraduate</option>
# <option value="diploma">Diploma</option>
# <option value="certificate">Certificate</option>
# <option value="masters-degree">Masters degree</option>
# <option value="postgraduate">Postgraduate</option>
# </select>
# </div>, <div class="checkbox">
# <input name="checkbox" type="checkbox"/><span>I agree to the <a href="https://www.w3docs.com/privacy-policy">Privacy Poalicy for W3Docs.</a></span>
# </div>]

# %%
## searching with a specific attribute values

tags = doc.find_all(['option'], text='Undergraduate', value='undergraduate')
print(tags)
# Out:
# [<option value="undergraduate">Undergraduate</option>]
# <ipython-input-25-41427d369596>:3: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tags = doc.find_all(['option'], text='Undergraduate', value='undergraduate')

# %%
## retrieving based on class value

tags = doc.find_all(class_='btn-item')
print(tags)
# Out:
# [<a class="btn-item" href="https://www.w3docs.com/learn-html.html">Learn HTML</a>, <a class="btn-item" href="https://www.w3docs.com/quiz/#">Select Quiz</a>]

# %%
import re

# %%
tags = doc.find_all(text=re.compile('\$.*'))
print(tags)
# Out:
# ['\n        $2345\n      ', '\n        $123\n        ']
# <ipython-input-28-eeef7bea4af6>:1: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   tags = doc.find_all(text=re.compile('\$.*'))

# %%
for tags in tags:
  print(tags.strip())
# Out:
# $2345
# $123

# %%
## limit the number of results

tags = doc.find_all(['option'], limit=2)
print(tags)
# Out:
# [<option color="blue" selected="" value="new-value">Course type*</option>, <option value="short-courses">Short courses</option>]

# %%
## modifying and saving the changes
tags = doc.find_all('input', type='text')

for tag in tags:
  tag['placeholder'] = 'Jane Doe'

with open('index4.html', 'w') as file:
  file.write(str(doc))

# %% [markdown]
# ---

# %%
url = 'https://coinmarketcap.com/'

result = requests.get(url).text
doc = BeautifulSoup(result, 'html.parser')

# %%
tbody = doc.tbody
print(tbody)
# Out:
# <tbody><tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">1</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/bitcoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="BTC logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Bitcoin</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">BTC</p></div></div></div></div></a></div></td><td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$60,155.90</span></div></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.21%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>0.68%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>6.53%</span></td><td style="text-align:end"><p class="sc-71024e3e-0 bbHOdE" color="text" data-sensors-click="true" font-size="1" style="white-space:nowrap"><span class="sc-11478e5d-0 chpohi">$1.19T</span><span class="sc-11478e5d-1 jfwGHx" data-nosnippet="true">$1,185,198,678,829</span></p></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-97d9abce-0 dlQYLv bJRjhz"><a class="cmc-link" href="/currencies/bitcoin/#markets"><p class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true" font-size="1">$28,743,262,909</p></a><div data-nosnippet="true"><p class="sc-71024e3e-0 hbcVUE" color="text2" data-sensors-click="true" font-size="0">478,717 BTC</p></div></div></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-552ef8b1-0 dlQYLv eOHbrv" data-sensors-click="true" style="cursor:pointer"><div class="sc-4c05d6ef-0 sc-552ef8b1-1 dlQYLv klYCgG"><p class="sc-71024e3e-0 hhmVNu" color="text" data-sensors-click="true" font-size="1" font-weight="medium">19,739,406 BTC</p></div><div class="sc-c50b4d85-0 lmZKdT" data-sensors-click="true" height="4" width="160"><div class="sc-c50b4d85-1 cKQRrC" height="4" width="151"></div></div></div></td><td style="text-align:end"><img alt="bitcoin-7d-price-graph" class="sc-7b3ac367-0 jUcYyN isUp" loading="lazy" src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1.svg"/></td></tr><tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">2</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/ethereum/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="ETH logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semib ...

# %%
trs = tbody.contents
print(trs[0].next_sibling)
print("\n")
print(trs[1].previous_sibling)
# Out:
# <tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">2</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/ethereum/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="ETH logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Ethereum</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">ETH</p></div></div></div></div></a></div></td><td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$2,680.06</span></div></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.28%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>0.18%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>6.27%</span></td><td style="text-align:end"><p class="sc-71024e3e-0 bbHOdE" color="text" data-sensors-click="true" font-size="1" style="white-space:nowrap"><span class="sc-11478e5d-0 chpohi">$321.89B</span><span class="sc-11478e5d-1 jfwGHx" data-nosnippet="true">$321,886,222,104</span></p></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-97d9abce-0 dlQYLv bJRjhz"><a class="cmc-link" href="/currencies/ethereum/#markets"><p class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true" font-size="1">$16,762,177,014</p></a><div data-nosnippet="true"><p class="sc-71024e3e-0 hbcVUE" color="text2" data-sensors-click="true" font-size="0">6,263,168 ETH</p></div></div></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-552ef8b1-0 dlQYLv eOHbrv" data-sensors-click="true" style="cursor:pointer"><div class="sc-4c05d6ef-0 sc-552ef8b1-1 dlQYLv klYCgG"><p class="sc-71024e3e-0 hhmVNu" color="text" data-sensors-click="true" font-size="1" font-weight="medium">120,272,421 ETH</p></div></div></td><td style="text-align:end"><img alt="ethereum-7d-price-graph" class="sc-7b3ac367-0 jUcYyN isUp" loading="lazy" src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1027.svg"/></td></tr>
#
#
# <tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">1</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/bitcoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="BTC logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Bitcoin</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">BTC</p></div></div></div></div></a></div></td><td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$60,155.90</span></div></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.21%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>0.68%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>6.53%</span></td><td style="text-align:end"><p class="sc-71024e3e-0 bbHOdE" color="text" data-sensors-click="true" font-size="1" style="white-space:nowrap"><span class="sc-11478e5d-0 chpohi">$1.19T</span><span class="sc-11478e5d-1 jfwGHx" data-nosnippet="true">$1,185,198,678,829</span></p></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-97d9abce-0 dlQYLv bJRjhz"><a class="cmc-link" href="/currencies/bitcoin/#markets"><p class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true" font-size="1">$28,743,262,909</p></a><div data-nosnippet="true"><p class="sc-71024e3e-0 hbcVUE" color="text2" data-sensors-click="true" font-size="0">478,717 BTC</p></div></div></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-552ef8b1-0 dlQYLv eOHbrv" data-sensors-click="true" style="cursor:pointer"><div class="sc-4c05d6ef-0 sc-552ef8b1-1 dlQYLv klYCgG"><p class="sc-71024e3e-0 hhmVNu" color="text" data-sensors-click="true" font-size="1" font-weight="medium">19,739,406 BTC</p></div><div class="sc-c50b4d85-0 lmZKdT" data-sensors-click="true" height="4" width="160"><div class="sc-c50b4d85-1 cKQRrC" height="4" width="151"></div></div></div></td><td style="text-align:end"><img alt="bitcoin-7d-price-graph" class="sc-7b3ac367-0 jUcYyN isUp" loading="lazy" src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1.svg"/></td></tr>

# %%
print(list(trs[0].next_siblings))
# Out:
# [<tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">2</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/ethereum/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="ETH logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Ethereum</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">ETH</p></div></div></div></div></a></div></td><td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$2,680.06</span></div></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.28%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>0.18%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>6.27%</span></td><td style="text-align:end"><p class="sc-71024e3e-0 bbHOdE" color="text" data-sensors-click="true" font-size="1" style="white-space:nowrap"><span class="sc-11478e5d-0 chpohi">$321.89B</span><span class="sc-11478e5d-1 jfwGHx" data-nosnippet="true">$321,886,222,104</span></p></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-97d9abce-0 dlQYLv bJRjhz"><a class="cmc-link" href="/currencies/ethereum/#markets"><p class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true" font-size="1">$16,762,177,014</p></a><div data-nosnippet="true"><p class="sc-71024e3e-0 hbcVUE" color="text2" data-sensors-click="true" font-size="0">6,263,168 ETH</p></div></div></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-552ef8b1-0 dlQYLv eOHbrv" data-sensors-click="true" style="cursor:pointer"><div class="sc-4c05d6ef-0 sc-552ef8b1-1 dlQYLv klYCgG"><p class="sc-71024e3e-0 hhmVNu" color="text" data-sensors-click="true" font-size="1" font-weight="medium">120,272,421 ETH</p></div></div></td><td style="text-align:end"><img alt="ethereum-7d-price-graph" class="sc-7b3ac367-0 jUcYyN isUp" loading="lazy" src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1027.svg"/></td></tr>, <tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">3</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/tether/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="USDT logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/825.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Tether</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors- ...

# %%
print(trs[0].parent.name)
# Out:
# tbody

# %%
print(list(trs[0].parent.descendants)) ## can use .contents as well
# Out:
# [<tr style="cursor:pointer"><td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td><td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">1</p></td><td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/bitcoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="BTC logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Bitcoin</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">BTC</p></div></div></div></div></a></div></td><td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$60,155.90</span></div></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>1.21%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>0.68%</span></td><td style="text-align:end"><span class="sc-a59753b0-0 cmnujh"><span class="icon-Caret-up" style="width:12px;height:18px;display:inline-block"></span>6.53%</span></td><td style="text-align:end"><p class="sc-71024e3e-0 bbHOdE" color="text" data-sensors-click="true" font-size="1" style="white-space:nowrap"><span class="sc-11478e5d-0 chpohi">$1.19T</span><span class="sc-11478e5d-1 jfwGHx" data-nosnippet="true">$1,185,198,678,829</span></p></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-97d9abce-0 dlQYLv bJRjhz"><a class="cmc-link" href="/currencies/bitcoin/#markets"><p class="sc-71024e3e-0 bbHOdE font_weight_500" color="text" data-sensors-click="true" font-size="1">$28,743,262,909</p></a><div data-nosnippet="true"><p class="sc-71024e3e-0 hbcVUE" color="text2" data-sensors-click="true" font-size="0">478,717 BTC</p></div></div></td><td style="text-align:end"><div class="sc-4c05d6ef-0 sc-552ef8b1-0 dlQYLv eOHbrv" data-sensors-click="true" style="cursor:pointer"><div class="sc-4c05d6ef-0 sc-552ef8b1-1 dlQYLv klYCgG"><p class="sc-71024e3e-0 hhmVNu" color="text" data-sensors-click="true" font-size="1" font-weight="medium">19,739,406 BTC</p></div><div class="sc-c50b4d85-0 lmZKdT" data-sensors-click="true" height="4" width="160"><div class="sc-c50b4d85-1 cKQRrC" height="4" width="151"></div></div></div></td><td style="text-align:end"><img alt="bitcoin-7d-price-graph" class="sc-7b3ac367-0 jUcYyN isUp" loading="lazy" src="https://s3.coinmarketcap.com/generated/sparklines/web/7d/2781/1.svg"/></td></tr>, <td><span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span></td>, <span class="tooltip tooltip-right" data-text="Add to Main Watchlist"><span class="icon-Star" style="color:var(--color-light-neutral-4)"></span></span>, <span class="icon-Star" style="color:var(--color-light-neutral-4)"></span>, <td style="text-align:start"><p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">1</p></td>, <p class="sc-71024e3e-0 jBOvmG" color="text2" data-sensors-click="true" font-size="14">1</p>, '1', <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/bitcoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="BTC logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" sr ...

# %%
## just getting the certain things from a webpage by indexing
prices = {}

for tr in trs:
  for td in tr.contents[2:4]:
    print(td)
    print()
# Out:
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/bitcoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="BTC logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Bitcoin</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">BTC</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$60,155.90</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/ethereum/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="ETH logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1027.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Ethereum</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">ETH</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$2,680.06</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/tether/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="USDT logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/825.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Tether</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">USDT</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$1.00</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/bnb/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="BNB logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/1839.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">BNB</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">BNB</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$519.35</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/solana/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="SOL logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/5426.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Solana</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">SOL</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$146.53</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/usd-coin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="USDC logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/3408.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">USDC</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">USDC</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$0.9999</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/xrp/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="XRP logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/52.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">XRP</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">XRP</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$0.5781</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/toncoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="TON logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/11419.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Toncoin</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">TON</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$6.34</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/dogecoin/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="DOGE logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/74.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Dogecoin</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">DOGE</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$0.1061</span></div></td>
#
# <td style="text-align:start"><div class="sc-4c05d6ef-0 bLqliP" display="flex"><a class="cmc-link" href="/currencies/cardano/"><div class="sc-4c05d6ef-0 sc-1c5f2868-0 dlQYLv ksLgtQ" data-sensors-click="true"><img alt="ADA logo" class="coin-logo" decoding="async" fetchpriority="low" loading="lazy" src="https://s2.coinmarketcap.com/static/img/coins/64x64/2010.png"/><div class="sc-4c05d6ef-0 sc-1c5f2868-1 dlQYLv gunIRl"><div class="sc-4c05d6ef-0 sc-1c5f2868-2 dlQYLv bszTYj hide-ranking-number"><p class="sc-71024e3e-0 ehyBa-d" color="text" data-sensors-click="true" font-size="1" font-weight="semibold">Cardano</p><div class="sc-1c5f2868-3 hHWqgz" data-nosnippet="true"><p class="sc-71024e3e-0 OqPKt coin-item-symbol" color="text3" data-sensors-click="true" font-size="1">ADA</p></div></div></div></div></a></div></td>
#
# <td style="text-align:end"><div class="sc-b3fc6b7-0 dzgUIj"><span>$0.3383</span></div></td>
#
# <td><a class="cmc-link" href="/currencies/tron/"><span class="circle"></span><span>TRON</span><span class="crypto-symbol">TRX</span></a></td>
#
# <td>$<!-- -->0.13</td>
#
# <td><a class="cmc-link" href="/currencies/avalanche/"><span class="circle"></span><span>Avalanche</span><span class="crypto-symbol">AVAX</span></a></td>
#
# <td>$<!-- -->21.26</td>
#
# <td><a class="cmc-link" href="/currencies/shiba-inu/"><span class="circle"></span><span>Shiba Inu</span><span class="crypto-symbol">SHIB</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/bitcoin-cash/"><span class="circle"></span><span>Bitcoin Cash</span><span class="crypto-symbol">BCH</span></a></td>
#
# <td>$<!-- -->350.63</td>
#
# <td><a class="cmc-link" href="/currencies/polkadot-new/"><span class="circle"></span><span>Polkadot</span><span class="crypto-symbol">DOT</span></a></td>
#
# <td>$<!-- -->4.53</td>
#
# <td><a class="cmc-link" href="/currencies/chainlink/"><span class="circle"></span><span>Chainlink</span><span class="crypto-symbol">LINK</span></a></td>
#
# <td>$<!-- -->10.41</td>
#
# <td><a class="cmc-link" href="/currencies/unus-sed-leo/"><span class="circle"></span><span>UNUS SED LEO</span><span class="crypto-symbol">LEO</span></a></td>
#
# <td>$<!-- -->5.80</td>
#
# <td><a class="cmc-link" href="/currencies/multi-collateral-dai/"><span class="circle"></span><span>Dai</span><span class="crypto-symbol">DAI</span></a></td>
#
# <td>$<!-- -->1.00</td>
#
# <td><a class="cmc-link" href="/currencies/litecoin/"><span class="circle"></span><span>Litecoin</span><span class="crypto-symbol">LTC</span></a></td>
#
# <td>$<!-- -->62.94</td>
#
# <td><a class="cmc-link" href="/currencies/near-protocol/"><span class="circle"></span><span>NEAR Protocol</span><span class="crypto-symbol">NEAR</span></a></td>
#
# <td>$<!-- -->4.11</td>
#
# <td><a class="cmc-link" href="/currencies/polygon/"><span class="circle"></span><span>Polygon</span><span class="crypto-symbol">MATIC</span></a></td>
#
# <td>$<!-- -->0.42</td>
#
# <td><a class="cmc-link" href="/currencies/kaspa/"><span class="circle"></span><span>Kaspa</span><span class="crypto-symbol">KAS</span></a></td>
#
# <td>$<!-- -->0.17</td>
#
# <td><a class="cmc-link" href="/currencies/uniswap/"><span class="circle"></span><span>Uniswap</span><span class="crypto-symbol">UNI</span></a></td>
#
# <td>$<!-- -->6.28</td>
#
# <td><a class="cmc-link" href="/currencies/pepe/"><span class="circle"></span><span>Pepe</span><span class="crypto-symbol">PEPE</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/internet-computer/"><span class="circle"></span><span>Internet Computer</span><span class="crypto-symbol">ICP</span></a></td>
#
# <td>$<!-- -->7.18</td>
#
# <td><a class="cmc-link" href="/currencies/aptos/"><span class="circle"></span><span>Aptos</span><span class="crypto-symbol">APT</span></a></td>
#
# <td>$<!-- -->6.57</td>
#
# <td><a class="cmc-link" href="/currencies/stellar/"><span class="circle"></span><span>Stellar</span><span class="crypto-symbol">XLM</span></a></td>
#
# <td>$<!-- -->0.10</td>
#
# <td><a class="cmc-link" href="/currencies/ethereum-classic/"><span class="circle"></span><span>Ethereum Classic</span><span class="crypto-symbol">ETC</span></a></td>
#
# <td>$<!-- -->18.94</td>
#
# <td><a class="cmc-link" href="/currencies/monero/"><span class="circle"></span><span>Monero</span><span class="crypto-symbol">XMR</span></a></td>
#
# <td>$<!-- -->150.82</td>
#
# <td><a class="cmc-link" href="/currencies/sui/"><span class="circle"></span><span>Sui</span><span class="crypto-symbol">SUI</span></a></td>
#
# <td>$<!-- -->0.95</td>
#
# <td><a class="cmc-link" href="/currencies/cronos/"><span class="circle"></span><span>Cronos</span><span class="crypto-symbol">CRO</span></a></td>
#
# <td>$<!-- -->0.09</td>
#
# <td><a class="cmc-link" href="/currencies/stacks/"><span class="circle"></span><span>Stacks</span><span class="crypto-symbol">STX</span></a></td>
#
# <td>$<!-- -->1.53</td>
#
# <td><a class="cmc-link" href="/currencies/okb/"><span class="circle"></span><span>OKB</span><span class="crypto-symbol">OKB</span></a></td>
#
# <td>$<!-- -->36.83</td>
#
# <td><a class="cmc-link" href="/currencies/artificial-superintelligence-alliance/"><span class="circle"></span><span>Artificial Superintelligence Alliance</span><span class="crypto-symbol">FET</span></a></td>
#
# <td>$<!-- -->0.88</td>
#
# <td><a class="cmc-link" href="/currencies/filecoin/"><span class="circle"></span><span>Filecoin</span><span class="crypto-symbol">FIL</span></a></td>
#
# <td>$<!-- -->3.71</td>
#
# <td><a class="cmc-link" href="/currencies/bittensor/"><span class="circle"></span><span>Bittensor</span><span class="crypto-symbol">TAO</span></a></td>
#
# <td>$<!-- -->282.79</td>
#
# <td><a class="cmc-link" href="/currencies/mantle/"><span class="circle"></span><span>Mantle</span><span class="crypto-symbol">MNT</span></a></td>
#
# <td>$<!-- -->0.61</td>
#
# <td><a class="cmc-link" href="/currencies/first-digital-usd/"><span class="circle"></span><span>First Digital USD</span><span class="crypto-symbol">FDUSD</span></a></td>
#
# <td>$<!-- -->1.00</td>
#
# <td><a class="cmc-link" href="/currencies/cosmos/"><span class="circle"></span><span>Cosmos</span><span class="crypto-symbol">ATOM</span></a></td>
#
# <td>$<!-- -->4.99</td>
#
# <td><a class="cmc-link" href="/currencies/maker/"><span class="circle"></span><span>Maker</span><span class="crypto-symbol">MKR</span></a></td>
#
# <td>$<!-- -->2086.06</td>
#
# <td><a class="cmc-link" href="/currencies/arbitrum/"><span class="circle"></span><span>Arbitrum</span><span class="crypto-symbol">ARB</span></a></td>
#
# <td>$<!-- -->0.58</td>
#
# <td><a class="cmc-link" href="/currencies/hedera/"><span class="circle"></span><span>Hedera</span><span class="crypto-symbol">HBAR</span></a></td>
#
# <td>$<!-- -->0.05</td>
#
# <td><a class="cmc-link" href="/currencies/vechain/"><span class="circle"></span><span>VeChain</span><span class="crypto-symbol">VET</span></a></td>
#
# <td>$<!-- -->0.02</td>
#
# <td><a class="cmc-link" href="/currencies/immutable-x/"><span class="circle"></span><span>Immutable</span><span class="crypto-symbol">IMX</span></a></td>
#
# <td>$<!-- -->1.19</td>
#
# <td><a class="cmc-link" href="/currencies/injective/"><span class="circle"></span><span>Injective</span><span class="crypto-symbol">INJ</span></a></td>
#
# <td>$<!-- -->19.04</td>
#
# <td><a class="cmc-link" href="/currencies/render/"><span class="circle"></span><span>Render</span><span class="crypto-symbol">RENDER</span></a></td>
#
# <td>$<!-- -->4.71</td>
#
# <td><a class="cmc-link" href="/currencies/dogwifhat/"><span class="circle"></span><span>dogwifhat</span><span class="crypto-symbol">WIF</span></a></td>
#
# <td>$<!-- -->1.69</td>
#
# <td><a class="cmc-link" href="/currencies/optimism-ethereum/"><span class="circle"></span><span>Optimism</span><span class="crypto-symbol">OP</span></a></td>
#
# <td>$<!-- -->1.35</td>
#
# <td><a class="cmc-link" href="/currencies/aave/"><span class="circle"></span><span>Aave</span><span class="crypto-symbol">AAVE</span></a></td>
#
# <td>$<!-- -->95.88</td>
#
# <td><a class="cmc-link" href="/currencies/arweave/"><span class="circle"></span><span>Arweave</span><span class="crypto-symbol">AR</span></a></td>
#
# <td>$<!-- -->21.64</td>
#
# <td><a class="cmc-link" href="/currencies/the-graph/"><span class="circle"></span><span>The Graph</span><span class="crypto-symbol">GRT</span></a></td>
#
# <td>$<!-- -->0.14</td>
#
# <td><a class="cmc-link" href="/currencies/bonk1/"><span class="circle"></span><span>Bonk</span><span class="crypto-symbol">BONK</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/bitget-token-new/"><span class="circle"></span><span>Bitget Token</span><span class="crypto-symbol">BGB</span></a></td>
#
# <td>$<!-- -->0.92</td>
#
# <td><a class="cmc-link" href="/currencies/celestia/"><span class="circle"></span><span>Celestia</span><span class="crypto-symbol">TIA</span></a></td>
#
# <td>$<!-- -->5.93</td>
#
# <td><a class="cmc-link" href="/currencies/theta-network/"><span class="circle"></span><span>Theta Network</span><span class="crypto-symbol">THETA</span></a></td>
#
# <td>$<!-- -->1.19</td>
#
# <td><a class="cmc-link" href="/currencies/floki-inu/"><span class="circle"></span><span>FLOKI</span><span class="crypto-symbol">FLOKI</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/thorchain/"><span class="circle"></span><span>THORChain</span><span class="crypto-symbol">RUNE</span></a></td>
#
# <td>$<!-- -->3.46</td>
#
# <td><a class="cmc-link" href="/currencies/notcoin/"><span class="circle"></span><span>Notcoin</span><span class="crypto-symbol">NOT</span></a></td>
#
# <td>$<!-- -->0.01</td>
#
# <td><a class="cmc-link" href="/currencies/helium/"><span class="circle"></span><span>Helium</span><span class="crypto-symbol">HNT</span></a></td>
#
# <td>$<!-- -->6.91</td>
#
# <td><a class="cmc-link" href="/currencies/jupiter-ag/"><span class="circle"></span><span>Jupiter</span><span class="crypto-symbol">JUP</span></a></td>
#
# <td>$<!-- -->0.81</td>
#
# <td><a class="cmc-link" href="/currencies/pyth-network/"><span class="circle"></span><span>Pyth Network</span><span class="crypto-symbol">PYTH</span></a></td>
#
# <td>$<!-- -->0.29</td>
#
# <td><a class="cmc-link" href="/currencies/ondo-finance/"><span class="circle"></span><span>Ondo</span><span class="crypto-symbol">ONDO</span></a></td>
#
# <td>$<!-- -->0.75</td>
#
# <td><a class="cmc-link" href="/currencies/jasmy/"><span class="circle"></span><span>JasmyCoin</span><span class="crypto-symbol">JASMY</span></a></td>
#
# <td>$<!-- -->0.02</td>
#
# <td><a class="cmc-link" href="/currencies/fantom/"><span class="circle"></span><span>Fantom</span><span class="crypto-symbol">FTM</span></a></td>
#
# <td>$<!-- -->0.35</td>
#
# <td><a class="cmc-link" href="/currencies/algorand/"><span class="circle"></span><span>Algorand</span><span class="crypto-symbol">ALGO</span></a></td>
#
# <td>$<!-- -->0.12</td>
#
# <td><a class="cmc-link" href="/currencies/lido-dao/"><span class="circle"></span><span>Lido DAO</span><span class="crypto-symbol">LDO</span></a></td>
#
# <td>$<!-- -->1.06</td>
#
# <td><a class="cmc-link" href="/currencies/kucoin-token/"><span class="circle"></span><span>KuCoin Token</span><span class="crypto-symbol">KCS</span></a></td>
#
# <td>$<!-- -->7.98</td>
#
# <td><a class="cmc-link" href="/currencies/core-dao/"><span class="circle"></span><span>Core</span><span class="crypto-symbol">CORE</span></a></td>
#
# <td>$<!-- -->1.03</td>
#
# <td><a class="cmc-link" href="/currencies/sei/"><span class="circle"></span><span>Sei</span><span class="crypto-symbol">SEI</span></a></td>
#
# <td>$<!-- -->0.29</td>
#
# <td><a class="cmc-link" href="/currencies/based-brett/"><span class="circle"></span><span>Brett (Based)</span><span class="crypto-symbol">BRETT</span></a></td>
#
# <td>$<!-- -->0.09</td>
#
# <td><a class="cmc-link" href="/currencies/bitcoin-sv/"><span class="circle"></span><span>Bitcoin SV</span><span class="crypto-symbol">BSV</span></a></td>
#
# <td>$<!-- -->43.40</td>
#
# <td><a class="cmc-link" href="/currencies/flow/"><span class="circle"></span><span>Flow</span><span class="crypto-symbol">FLOW</span></a></td>
#
# <td>$<!-- -->0.55</td>
#
# <td><a class="cmc-link" href="/currencies/mantra/"><span class="circle"></span><span>MANTRA</span><span class="crypto-symbol">OM</span></a></td>
#
# <td>$<!-- -->0.94</td>
#
# <td><a class="cmc-link" href="/currencies/quant/"><span class="circle"></span><span>Quant</span><span class="crypto-symbol">QNT</span></a></td>
#
# <td>$<!-- -->64.55</td>
#
# <td><a class="cmc-link" href="/currencies/eos/"><span class="circle"></span><span>EOS</span><span class="crypto-symbol">EOS</span></a></td>
#
# <td>$<!-- -->0.52</td>
#
# <td><a class="cmc-link" href="/currencies/multiversx-egld/"><span class="circle"></span><span>MultiversX</span><span class="crypto-symbol">EGLD</span></a></td>
#
# <td>$<!-- -->27.37</td>
#
# <td><a class="cmc-link" href="/currencies/usdd/"><span class="circle"></span><span>USDD</span><span class="crypto-symbol">USDD</span></a></td>
#
# <td>$<!-- -->1.00</td>
#
# <td><a class="cmc-link" href="/currencies/paypal-usd/"><span class="circle"></span><span>PayPal USD</span><span class="crypto-symbol">PYUSD</span></a></td>
#
# <td>$<!-- -->1.00</td>
#
# <td><a class="cmc-link" href="/currencies/bittorrent-new/"><span class="circle"></span><span>BitTorrent [New]</span><span class="crypto-symbol">BTT</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/axie-infinity/"><span class="circle"></span><span>Axie Infinity</span><span class="crypto-symbol">AXS</span></a></td>
#
# <td>$<!-- -->4.82</td>
#
# <td><a class="cmc-link" href="/currencies/akash-network/"><span class="circle"></span><span>Akash Network</span><span class="crypto-symbol">AKT</span></a></td>
#
# <td>$<!-- -->2.81</td>
#
# <td><a class="cmc-link" href="/currencies/neo/"><span class="circle"></span><span>Neo</span><span class="crypto-symbol">NEO</span></a></td>
#
# <td>$<!-- -->9.68</td>
#
# <td><a class="cmc-link" href="/currencies/sats/"><span class="circle"></span><span>SATS</span><span class="crypto-symbol">1000SATS</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/tezos/"><span class="circle"></span><span>Tezos</span><span class="crypto-symbol">XTZ</span></a></td>
#
# <td>$<!-- -->0.68</td>
#
# <td><a class="cmc-link" href="/currencies/zcash/"><span class="circle"></span><span>Zcash</span><span class="crypto-symbol">ZEC</span></a></td>
#
# <td>$<!-- -->41.25</td>
#
# <td><a class="cmc-link" href="/currencies/gatetoken/"><span class="circle"></span><span>GateToken</span><span class="crypto-symbol">GT</span></a></td>
#
# <td>$<!-- -->7.21</td>
#
# <td><a class="cmc-link" href="/currencies/dydx-chain/"><span class="circle"></span><span>dYdX (Native)</span><span class="crypto-symbol">DYDX</span></a></td>
#
# <td>$<!-- -->1.06</td>
#
# <td><a class="cmc-link" href="/currencies/starknet-token/"><span class="circle"></span><span>Starknet</span><span class="crypto-symbol">STRK</span></a></td>
#
# <td>$<!-- -->0.40</td>
#
# <td><a class="cmc-link" href="/currencies/flare/"><span class="circle"></span><span>Flare</span><span class="crypto-symbol">FLR</span></a></td>
#
# <td>$<!-- -->0.02</td>
#
# <td><a class="cmc-link" href="/currencies/onbeam/"><span class="circle"></span><span>Beam</span><span class="crypto-symbol">BEAM</span></a></td>
#
# <td>$<!-- -->0.01</td>
#
# <td><a class="cmc-link" href="/currencies/ethereum-name-service/"><span class="circle"></span><span>Ethereum Name Service</span><span class="crypto-symbol">ENS</span></a></td>
#
# <td>$<!-- -->19.51</td>
#
# <td><a class="cmc-link" href="/currencies/ordi/"><span class="circle"></span><span>ORDI</span><span class="crypto-symbol">ORDI</span></a></td>
#
# <td>$<!-- -->30.63</td>
#
# <td><a class="cmc-link" href="/currencies/ecash/"><span class="circle"></span><span>eCash</span><span class="crypto-symbol">XEC</span></a></td>
#
# <td>$<!-- -->0.00</td>
#
# <td><a class="cmc-link" href="/currencies/tether-gold/"><span class="circle"></span><span>Tether Gold</span><span class="crypto-symbol">XAUt</span></a></td>
#
# <td>$<!-- -->2470.09</td>
#
# <td><a class="cmc-link" href="/currencies/ethena/"><span class="circle"></span><span>Ethena</span><span class="crypto-symbol">ENA</span></a></td>
#
# <td>$<!-- -->0.34</td>
#
# <td><a class="cmc-link" href="/currencies/the-sandbox/"><span class="circle"></span><span>The Sandbox</span><span class="crypto-symbol">SAND</span></a></td>
#
# <td>$<!-- -->0.26</td>
#
# <td><a class="cmc-link" href="/currencies/nexo/"><span class="circle"></span><span>Nexo</span><span class="crypto-symbol">NEXO</span></a></td>
#
# <td>$<!-- -->1.07</td>
#
# <td><a class="cmc-link" href="/currencies/conflux-network/"><span class="circle"></span><span>Conflux</span><span class="crypto-symbol">CFX</span></a></td>
#
# <td>$<!-- -->0.13</td>
#
# <td><a class="cmc-link" href="/currencies/wormhole/"><span class="circle"></span><span>Wormhole</span><span class="crypto-symbol">W</span></a></td>
#
# <td>$<!-- -->0.22</td>
#
# <td><a class="cmc-link" href="/currencies/worldcoin-org/"><span class="circle"></span><span>Worldcoin</span><span class="crypto-symbol">WLD</span></a></td>
#
# <td>$<!-- -->1.67</td>

# %%
## just getting the certain things from a webpage by indexing
prices = {}

for tr in trs[:10]:
  name, price =  tr.contents[2:4]
  fixed_name = name.p.string
  fixed_price = price.span.string
  prices[fixed_name] = fixed_price

print(prices)
# Out:
# {'Bitcoin': '$60,155.90', 'Ethereum': '$2,680.06', 'Tether': '$1.00', 'BNB': '$519.35', 'Solana': '$146.53', 'USDC': '$0.9999', 'XRP': '$0.5781', 'Toncoin': '$6.34', 'Dogecoin': '$0.1061', 'Cardano': '$0.3383'}

# %% [markdown]
# ---
#
#
#
# ---

# %%
gpu = input("What GPU are you looking for? ")
url= f"https://www.newegg.com/p/pl?d={gpu}&N=4131"
# Out:
# What GPU are you looking for? 3080

# %%
page = requests.get(url).text
doc  = BeautifulSoup(page, "html.parser")

## Getting the total number of pages with relevant products
page_text = doc.find(class_="list-tool-pagination-text")
page_text = page_text.strong.text
pages = int(page_text.split('/')[1])

print(pages)
# Out:
# 16

# %%
## getting the product names by filtering out with the class names

for page in range(1,pages+1):
  url= f"https://www.newegg.com/p/pl?d={gpu}&N=4131&pages={page}"
  page = requests.get(url).text
  doc  = BeautifulSoup(page, "html.parser")

  div = doc.find(class_="item-cells-wrap border-cells short-video-box items-grid-view four-cells expulsion-one-cell")
  items = div.find_all(string=re.compile(gpu))

  for item in items:
    parent = item.parent
    if parent.name !='a':
      continue
    link = parent['href']

    print(link)
    print(item)
    print("\n")
# Out:
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# ...
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
#
#
# https://www.newegg.com/p/1FT-0004-008J7
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
#
#
# https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/N82E16814932460
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000Y-00956
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
#
#
# https://www.newegg.com/p/1FT-000Y-00981
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
#
#
# https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
#
#
# https://www.newegg.com/p/1FT-0009-00BF6
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
#
#
# https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
#
#
# https://www.newegg.com/evga-ftw3-10g-p5-3897-kl-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814487541T
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
#
#
# https://www.newegg.com/p/1FT-000A-006K4
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
#
#
# https://www.newegg.com/p/1FT-000Y-009E2
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
#
#
# https://www.newegg.com/p/1FT-000Y-007N0
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/1FT-001K-00DF8
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/N82E16814137597
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/p/1FT-000P-004E8
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
#
#
# https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
#
#
# https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
#
#
# https://www.newegg.com/p/1FT-000P-005Y2
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
#
#
# https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
#
#
# https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
#
#
# https://www.newegg.com/p/1FT-000A-00434
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
#
#
# https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card

# %%
## getting the price
items_found={}

for page in range(1,pages+1):
  url= f"https://www.newegg.com/p/pl?d={gpu}&N=4131&pages={page}"
  page = requests.get(url).text
  doc  = BeautifulSoup(page, "html.parser")

  div = doc.find(class_="item-cells-wrap border-cells short-video-box items-grid-view four-cells expulsion-one-cell")
  items = div.find_all(string=re.compile(gpu))

  for item in items:
    parent = item.parent
    if parent.name !='a':
      continue
    link = parent['href']
    next_parent = item.find_parent(class_='item-container')
    price = next_parent.find(class_='price-current').strong.string

    items_found[item] = {'price': int(price.replace(',','')), 'link' : link}

# %%
for item in items_found:
  print(item)
  print(items_found[item])
  print("\n")
# Out:
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
# {'price': 459, 'link': 'https://www.newegg.com/p/1FT-0004-008J7'}
#
#
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
# {'price': 1569, 'link': 'https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2'}
#
#
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
# {'price': 736, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459'}
#
#
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
# {'price': 628, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1'}
#
#
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# {'price': 1099, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547'}
#
#
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
# {'price': 444, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3'}
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
# {'price': 999, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509'}
#
#
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
# {'price': 1699, 'link': 'https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9'}
#
#
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# {'price': 1099, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549'}
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
# {'price': 608, 'link': 'https://www.newegg.com/p/1FT-000Y-00981'}
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
# {'price': 999, 'link': 'https://www.newegg.com/p/1FT-000Y-00956'}
#
#
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
# {'price': 559, 'link': 'https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012'}
#
#
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
# {'price': 639, 'link': 'https://www.newegg.com/p/1FT-0009-00BF6'}
#
#
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
# {'price': 599, 'link': 'https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7'}
#
#
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# {'price': 1199, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7'}
#
#
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
# {'price': 1095, 'link': 'https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094'}
#
#
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
# {'price': 979, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541'}
#
#
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
# {'price': 799, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539'}
#
#
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
# {'price': 1095, 'link': 'https://www.newegg.com/p/1FT-000A-006K4'}
#
#
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
# {'price': 1095, 'link': 'https://www.newegg.com/p/1FT-000Y-009E2'}
#
#
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
# {'price': 799, 'link': 'https://www.newegg.com/p/1FT-000Y-007N0'}
#
#
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
# {'price': 1249, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983'}
#
#
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
# {'price': 739, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528'}
#
#
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
# {'price': 619, 'link': 'https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3'}
#
#
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
# {'price': 1108, 'link': 'https://www.newegg.com/p/1FT-000P-004E8'}
#
#
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
# {'price': 1079, 'link': 'https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660'}
#
#
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
# {'price': 599, 'link': 'https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816'}
#
#
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# {'price': 549, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520'}
#
#
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
# {'price': 424, 'link': 'https://www.newegg.com/p/1FT-000P-005Y2'}
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
# {'price': 799, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525'}
#
#
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
# {'price': 843, 'link': 'https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504'}
#
#
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
# {'price': 999, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533'}
#
#
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
# {'price': 459, 'link': 'https://www.newegg.com/p/1FT-000A-00434'}
#
#
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
# {'price': 509, 'link': 'https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T'}

# %%
sorted_items = sorted(items_found.items(), key=lambda x: x[1]['price'])

for item in sorted_items:
  print(item[0])
  print(item[1])
  print("\n")
# Out:
# Gaming XLR8 GeForce RTX 3080 10GB EPIC-X RGB Triple Fan (REVEL Model) 1710 MHz 19 Gbps 10GB GDDR6X Video Card
# {'price': 424, 'link': 'https://www.newegg.com/p/1FT-000P-005Y2'}
#
#
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KL, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate, LHR-
# {'price': 444, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kl/p/1FT-001K-00FM3'}
#
#
# NVIDIA GeForce RTX 3080 Founders Edition GDDR6X RTX 3080 FE Video Card
# {'price': 459, 'link': 'https://www.newegg.com/p/1FT-0004-008J7'}
#
#
# GIGABYTE GeForce RTX 3080 GAMING OC 10GB Video Card, GV-N3080GAMING OC-10GD (REV 2.0)(OPEN)
# {'price': 459, 'link': 'https://www.newegg.com/p/1FT-000A-00434'}
#
#
# ASUS TUF Gaming GeForce RTX 3080 TUF-RTX3080-O10G-GAMING Video Card
# {'price': 509, 'link': 'https://www.newegg.com/asus-tuf-gaming-tuf-rtx3080-o10g-gaming-nvidia-geforce-rtx-3080-10gb-gddr6x/p/N82E16814126452T'}
#
#
# EVGA GeForce RTX 3080 XC3 ULTRA GAMING Video Card, 10G-P5-3885-KR, 10GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# {'price': 549, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3885-kr/p/N82E16814487520'}
#
#
# BIOSTAR NEW GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Graphics Card NVIDIA RTX 3080 10GB Gaming Video Card 8Pin GPU Gamer
# {'price': 559, 'link': 'https://www.newegg.com/biostar-geforce-rtx-3080/p/1FT-003G-00012'}
#
#
# MSI Gaming GeForce RTX 3080 LHR 10GB GDRR6X 320-Bit HDMI/DP Nvlink Torx Fan 3 Ampere Architecture OC Graphics Card (RTX 3080 Ventus 3X Plus 10G OC LHR)
# {'price': 599, 'link': 'https://www.newegg.com/msi-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/1FT-0009-009J7'}
#
#
# MSI Ventus GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 VENTUS 3X PLUS 10G OC LHR
# {'price': 599, 'link': 'https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-ventus-3x-plus-10g-oc-lhr/p/N82E16814137816'}
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 O10G V2 GAMING Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification)
# {'price': 608, 'link': 'https://www.newegg.com/p/1FT-000Y-00981'}
#
#
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 Video Card RTX 3080 GAMING X TRIO 10G
# {'price': 619, 'link': 'https://www.newegg.com/msi-geforce-rtx-3080-rtx-3080-gaming-x-trio-10g/p/1FT-0009-00AR3'}
#
#
# GIGABYTE Vision OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080VISION OC-10GD (rev. 2.0) (LHR)
# {'price': 628, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080vision-oc-10gd/p/1FT-000A-006D1'}
#
#
# MSI Gaming GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 GAMING Z TRIO 10G LHR
# {'price': 639, 'link': 'https://www.newegg.com/p/1FT-0009-00BF6'}
#
#
# GIGABYTE Gaming OC GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 ATX Video Card GV-N3080GAMING OC-10GD (rev. 2.0) (LHR)
# {'price': 736, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-gv-n3080gaming-oc-10gd/p/N82E16814932459'}
#
#
# GIGABYTE GV-N308TGAMING OC-12GD Gaming GeForce RTX 3080 Ti Video Card
# {'price': 739, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308tgaming-oc-12gd/p/1FT-000A-00528'}
#
#
# GIGABYTE AORUS GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card GV-N308TAORUS M-12GD
# {'price': 799, 'link': 'https://www.newegg.com/gigabyte-geforce-rtx-3080-ti-gv-n308taorus-m-12gd/p/N82E16814932539'}
#
#
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING -OPENBOX
# {'price': 799, 'link': 'https://www.newegg.com/p/1FT-000Y-007N0'}
#
#
# ASUS TUF Gaming NVIDIA GeForce RTX 3080 V2 OC Edition Graphics Card (PCIe 4.0, 10GB GDDR6X, LHR, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II)
# {'price': 799, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-tuf-rtx3080-o10g-v2-gaming/p/N82E16814126525'}
#
#
# ZOTAC GAMING GeForce RTX 3080 Trinity OC 10GB GDDR6X 320-bit 19 Gbps PCIE 4.0 Gaming Graphics Card, IceStorm 2.0 Advanced Cooling, SPECTRA 2.0 RGB Lighting, ZT-A30800J-10P
# {'price': 843, 'link': 'https://www.newegg.com/zotac-geforce-rtx-3080-zt-t30800j-10p/p/N82E16814500504'}
#
#
# EVGA GeForce RTX 3080 FTW3 ULTRA GAMING Video Card, 10G-P5-3897-KL, 10GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate, LHR
# {'price': 979, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-10g-p5-3897-kl/p/N82E16814487541'}
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card TUF-RTX3080TI-O12G-GAMING
# {'price': 999, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-ti-tuf-rtx3080ti-o12g-gaming/p/N82E16814126509'}
#
#
# ASUS TUF Gaming GeForce RTX 3080 Ti OC Edition Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Dual Ball Fan Bearings, Military-grade Certification, GPU Tweak II), TUF-RTX3080TI-O12G
# {'price': 999, 'link': 'https://www.newegg.com/p/1FT-000Y-00956'}
#
#
# ASUS ROG STRIX GeForce RTX 3080 10GB GDDR6X PCI Express 4.0 x16 ATX Video Card ROG-STRIX-RTX3080-O10G-WHITE-V2 (LHR)
# {'price': 999, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-rtx3080-o10g-wht-v2/p/N82E16814126533'}
#
#
# MSI Suprim GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 ATX Video Card RTX 3080 Ti SUPRIM X 12G
# {'price': 1079, 'link': 'https://www.newegg.com/msi-geforce-rtx-3080-ti-suprim-x-12g/p/N82E16814137660'}
#
#
# NVIDIA GeForce RTX 3080 Ti 12GB GDDR6X PCI Express 4.0 Video Card GEFORCE RTX 3080 Ti FE
# {'price': 1095, 'link': 'https://www.newegg.com/nvidia-geforce-rtx-3080-ti-fe/p/N82E16814132094'}
#
#
# GIGABYTE GeForce RTX 3080 Ti Gaming OC 12G Graphics Card, 3X WINDFORCE Fans, 12GB 384-Bit GDDR6X,
# {'price': 1095, 'link': 'https://www.newegg.com/p/1FT-000A-006K4'}
#
#
# ASUS ROG Strix GeForce RTX 3080 Ti OC Edition Gaming Graphics Card (PCIe 4.0, 12GB GDDR6X, HDMI 2.1, DisplayPort 1.4a, Axial-tech Fan Design, 2.9-slot), ROG-STRIX-RTX3080TI-O12G-GAMING
# {'price': 1095, 'link': 'https://www.newegg.com/p/1FT-000Y-009E2'}
#
#
# EVGA GeForce RTX 3080 Ti FTW3 ULTRA GAMING Video Card, 12G-P5-3967-KR, 12GB GDDR6X, iCX3 Technology, ARGB LED, Metal Backplate
# {'price': 1099, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3967-kr/p/N82E16814487547'}
#
#
# EVGA GeForce RTX 3080 Ti XC3 GAMING Video Card, 12G-P5-3953-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# {'price': 1099, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3953-kr/p/N82E16814487549'}
#
#
# PNY GeForce RTX 3080 10GB XLR8 Gaming Revel Epic-X RGB Triple Fan Graphics Card LHR
# {'price': 1108, 'link': 'https://www.newegg.com/p/1FT-000P-004E8'}
#
#
# EVGA GeForce RTX 3080 Ti XC3 ULTRA GAMING Video Card, 12G-P5-3955-KR, 12GB GDDR6X, iCX3 Cooling, ARGB LED, Metal Backplate
# {'price': 1199, 'link': 'https://www.newegg.com/evga-geforce-rtx-3080-ti-12g-p5-3955-kr/p/1FT-001K-00FS7'}
#
#
# ASUS GeForce RTX 3080 Ti TUF 12GB GDDR6X TUF-RTX3080TI-12G-GAMING Video Graphic Card GPU
# {'price': 1249, 'link': 'https://www.newegg.com/asus-geforce-rtx-3080-ti/p/1FT-000Y-00983'}
#
#
# AVGPC Quiet Series Gaming PC | Intel i9 11900KF 5.3Hz Max Boost | RTX 3080 10GB | 32GB 3600MHz DDR4 | 1TB NVME M.2 SSD | 360MM AIO Liquid Cooling | ARGB Fans | WiFi/AC | MB520 Style Case | Windows 11
# {'price': 1569, 'link': 'https://www.newegg.com/avgpc-quiet-3080/p/3D5-002N-00042?Item=9SIB5FPJUR1825&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJUR1825-_-3080-_-3080-_-2'}
#
#
# AVGPC Blizzard Series Gaming PC - Intel i9-11900KF 3.5GHz, RTX 3080 10GB, 32GB 3600MHz DDR4, 2TB NVME M.2 SSD, 360mm Liquid Cooler, Wifi/AC, TD500 White Case, Windows 11 NVIDIA GeForce RTX 3080
# {'price': 1699, 'link': 'https://www.newegg.com/avgpc-blizzard-3090/p/3D5-002N-00046?Item=9SIB5FPJV66729&cm_sp=SP-_-2574594-_-0-_-0-_-9SIB5FPJV66729-_-3080-_-3080-_-9'}
